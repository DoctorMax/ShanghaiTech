# %% [markdown]
# ## Problem 2. scRNA-seq data and Autoencoders (20 points)

# %% [markdown]
# **Background:** Single-cell RNA-seq (scRNA-seq) data are often noisy and sparse, e.g. only a fraction of transcribed RNAs are captured in the sequencing due to the difficulty of amplifying a small signal from a single cell. While there are many genes expressed in a cell at any given time, two entirely different RNA-seq profiles could come from cells with similar expression levels. In this assignment, you will explore how to utilize autoencoders to identify clusters of scRNA-seq profiles. These clusters could represent varying expression profiles from cells of the same cell type, such as the profiles that you might see in different phases of the cell cycle.
#
# **Dataset:** Facing these challenges, simulation is important for conducting repeatable experiments with ground truth to test the performance of methods. Splatter is a software package for generating such simulated scRNA-seq count data, which can be used for evaluation. The data are provided in the form of normalized log counts across 1000 genes in 5000 cells. The gene expression matrix is provided as ./counts.npy, and the label file is ./labels.txt.

# %% [markdown]
# Given the skeleton code below, you should fill out the 'TBD' parts:
#
# **1. [12 points]** Train an Autoencoder to learn the distribution of scRNA-seq counts (refer to **'Implementation Notes'** to get more details of network).
#
# (a) [8 points] Finish the **Autoencoder** code (from 'define model' to 'obtain latent vectors'). Use latent embedding sizes (i.e. the size of the output of the encoder, and the input to the decoder) of 5, 10, 50, and 100.
#
# (b) [4 points] Report and compare their reconstruction Mean Squared Errors (MSEs). How does the size of the latent space affect the reconstruction MSE? (Please draw the loss function of MSE over epochs in the training and describe your observation).
#
#
# **2. [8 points]** Analyze the learned encodings. We have provided code to produce a PCA plot and a t-SNE plot of the raw RNA-seq data.
#
# (a) [3 points] Adapt the provided code to make PCA and t-SNE plots of the data reconstructed by the 4 autoencoders.
#
# (b) [3 points] Take the trained Encoders and make PCA and t-SNE plots of the latent vectors. Remember to draw plots for all the 4 autoencoders.
#
# (c) [1 points] Report the plots of the original data with those of the reconstructed data. How are the PCA and t-SNE plots of the reconstructed data qualitatively different from those of the original data?
#
# (d) [1 points] Report the plots of the original data with the plots of the latent vectors. How do the various embedding sizes change the quality of clustering?

# %%
import os
import sys
import numpy as np
import pandas as pd
import time

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import torch
from torch import optim
from torch import nn
from torch.utils.data import DataLoader

# import tensorflow as tf
# from tensorflow import keras
# %matplotlib inline


# Terminology Note: Latent vector = Latent Representation = Encoding = Output of Encoder

# %% [markdown]
# ### Parameters, loading data and helper function

# %%
num_epochs = 100
batch_size = 128
l_r = 1e-4
latent_size = [5,10,50,100]

# Helper method as an example to return the output mask
def return_out_mask(batch_data: np.array) -> np.array:
    '''
    Input: NxM np.array of counts data
    Output: NxM np.array filled with 1 corresponding to non-zero inputs
            and 0 corresponding to dropped inputs
    '''
    batch_data = batch_data.detach().numpy()
    zero_indices = np.nonzero(batch_data == 0)#得到0的位置
    mask = np.ones_like(batch_data)
    zeros = np.zeros_like(batch_data)
    mask[zero_indices] = zeros[zero_indices] # Fills in 0's into appropriate indices
    mask=torch.from_numpy(mask)
#     mask=torch.tensor(mask)
    return mask


# Load Data
dataset = np.load('counts.npy')
labels = np.loadtxt("labels.txt")
print('labels shape: ',labels.shape)
print('dataset shape: ',dataset.shape)
pd.DataFrame(dataset)[:5] # 5000 x 1000 (cell x gene)
# Out:
# labels shape:  (5000,)
# dataset shape:  (5000, 1000)
#         0         1         2         3         4    5         6        7    \
# 0  4.818027  0.000000  0.000000  0.000000  0.000000  0.0  0.000000  0.00000
# 1  4.949290  5.332359  4.106732  4.176539  0.000000  0.0  0.000000  0.00000
# 2  4.590253  4.791590  0.000000  4.137063  4.791590  0.0  0.000000  0.00000
# 3  5.599136  0.000000  0.000000  3.516551  0.000000  0.0  0.000000  3.25479
# 4  3.184195  5.290426  0.000000  3.356862  3.650348  0.0  3.356862  0.00000
#
#         8    9    ...       990       991       992       993       994  \
# 0  3.595109  0.0  ...  0.000000  7.875205  0.000000  5.403121  6.033264
# 1  5.100612  0.0  ...  3.695760  5.863619  3.956085  5.170709  5.609743
# 2  3.563473  0.0  ...  0.000000  8.038405  3.563473  5.001115  5.445224
# 3  4.735300  0.0  ...  4.513363  8.495263  4.388123  5.284629  5.481427
# 4  0.000000  0.0  ...  0.000000  7.935692  0.000000  0.000000  4.591724
#
#         995  996       997        998       999
# 0  4.332443  0.0  5.625551   9.738974  4.711081
# 1  5.820660  0.0  5.477707  10.617377  3.377886
# 2  5.294245  0.0  6.289117   9.903455  4.013606
# 3  4.881876  0.0  6.055585  10.006094  3.837205
# 4  4.591724  0.0  5.877299   9.279790  4.284677
#
# [5 rows x 1000 columns]

# %% [markdown]
# **Implementation Notes:**
#
# (1) Each Autoencoder should have 5 layers, with sizes 1000, 100, 10, 100 and 1000 from input to output, respectively.
#
# (2) Test your AEs with ~200 epochs.
#
# (3) Use a couple of dropout layers to help prevent overfitting on this small dataset. No validation set is necessary for this task.
#
# (4) You need to mask the outputs of the autoencoder that correspond to 0's (dropped counts) in the input. The autoencoder learns best when it is not forced to also learn to reconstruct the zeros in the input. This technique is known as
# gradient masking, and is commonly used in situations like this to prevent a training signal to reconstruct unimportant data.
# To acheive this, the reconstruction output of the autoencoder must be multiplied by a mask that zeros the corresponding
# dropped counts of the inputs, which ensures the gradient from that particular output is zero. Use MSE loss, and only average over
# the number of non-zero elements in the batch. You have been provided with a helper method in order to do the masking, which you may adapt or use as is.
#
# Hint: Feel free to experiment with the size of the network and hyperparameters.

# %% [markdown]
# ### Autoencoder

# %%
# Pytorch Dataloader
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
print(dataloader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x0000021B19B81DD8>

# %%
# Define Model, Optimizer, and Loss
#####################################################
class AutoEncoder(nn.Module):
    def __init__(self,latent_size):
        super(AutoEncoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(1000, 500),
            nn.Tanh(),
            nn.Dropout(p=0.2),
            nn.Linear(500, latent_size), 
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_size, 500),
            nn.Tanh(),
            nn.Dropout(p=0.2),
            nn.Linear(500, 1000),
        )
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded
model0 = AutoEncoder(latent_size=latent_size[0])
model1 = AutoEncoder(latent_size=latent_size[1])
model2 = AutoEncoder(latent_size=latent_size[2])
model3 = AutoEncoder(latent_size=latent_size[3])
optimizer0 = torch.optim.Adam(model0.parameters(), lr=l_r)
optimizer1 = torch.optim.Adam(model1.parameters(), lr=l_r)
optimizer2 = torch.optim.Adam(model2.parameters(), lr=l_r)
optimizer3 = torch.optim.Adam(model3.parameters(), lr=l_r)
loss_func = nn.MSELoss()
#####################################################

# %%
# Training Loop
#####################################################
def train(model,optimizer):
    for epoch in range(num_epochs):
        time1=time.time()
        for step, data in enumerate(dataloader):
    #         print('step:',step)
    #         print('data.size:',data.size())
            encoded, decoded = model(data)
#             print('encoded.size:',encoded.size())
            decoded=decoded*return_out_mask(decoded)#梯度蒙板
            loss = loss_func(decoded, data)#自编码器的label就是输入数据
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        time2=time.time()
        print('Epoch :%i'%epoch,'//','train_loss:%.4f'%loss.data,'//','耗时:%.4f'%(time2-time1))#不输出tensor（）
    print('Encoded.shape:',encoded.shape)
#     return encoded,decoded
train(model0,optimizer0)
train(model1,optimizer1)
train(model2,optimizer2)
train(model3,optimizer3)
#####################################################

# Save model weights (Optional)
#####################################################
torch.save(model0,'AutoEncoder0.pkl')
torch.save(model1,'AutoEncoder1.pkl')
torch.save(model2,'AutoEncoder2.pkl')
torch.save(model3,'AutoEncoder3.pkl')
print('Training finished')
# model = torch.load('AutoEncoder.pkl')
#####################################################

# Obtain Encoded Representations & Reconstructions
#   Run just the trained encoder across dataset to obtain latent vectors
#####################################################
#集成在训练循环中了，输出了编码后的潜在矢量大小
#经观察不同的latent_size并没有太大的区别
#####################################################
# Out:
# d:\anaconda3\envs\cs286\lib\site-packages\torch\autograd\__init__.py:132: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   allow_unreachable=True)  # allow_unreachable flag
# Epoch :0 // train_loss:9.9310 // 耗时:0.7777
# Epoch :1 // train_loss:5.5899 // 耗时:0.6353
# Epoch :2 // train_loss:3.8673 // 耗时:0.5874
# Epoch :3 // train_loss:3.1568 // 耗时:0.6014
# Epoch :4 // train_loss:3.0566 // 耗时:0.5615
# Epoch :5 // train_loss:2.7166 // 耗时:0.5909
# Epoch :6 // train_loss:2.9658 // 耗时:0.6114
# Epoch :7 // train_loss:2.6584 // 耗时:0.5545
# Epoch :8 // train_loss:2.6261 // 耗时:0.5999
# Epoch :9 // train_loss:2.5699 // 耗时:0.5825
# Epoch :10 // train_loss:2.7800 // 耗时:0.5655
# Epoch :11 // train_loss:2.7529 // 耗时:0.5952
# Epoch :12 // train_loss:2.6042 // 耗时:0.6119
# Epoch :13 // train_loss:2.8329 // 耗时:0.6323
# Epoch :14 // train_loss:2.8469 // 耗时:0.5690
# Epoch :15 // train_loss:2.6136 // 耗时:0.6054
# Epoch :16 // train_loss:2.7041 // 耗时:0.5865
# Epoch :17 // train_loss:2.6969 // 耗时:0.5894
# Epoch :18 // train_loss:2.8106 // 耗时:0.5615
# Epoch :19 // train_loss:2.6525 // 耗时:0.5647
# Epoch :20 // train_loss:2.8039 // 耗时:0.6343
# Epoch :21 // train_loss:2.7861 // 耗时:0.5815
# Epoch :22 // train_loss:2.6715 // 耗时:0.6029
# Epoch :23 // train_loss:2.8517 // 耗时:0.6211
# Epoch :24 // train_loss:2.8380 // 耗时:0.6383
# Epoch :25 // train_loss:2.8109 // 耗时:0.5688
# Epoch :26 // train_loss:2.6154 // 耗时:0.5828
# Epoch :27 // train_loss:2.6122 // 耗时:0.6203
# Epoch :28 // train_loss:2.6822 // 耗时:0.5830
# Epoch :29 // train_loss:2.7644 // 耗时:0.5760
# Epoch :30 // train_loss:2.7239 // 耗时:0.6215
# Epoch :31 // train_loss:2.5606 // 耗时:0.5558
# Epoch :32 // train_loss:2.7052 // 耗时:0.5745
# Epoch :33 // train_loss:2.7882 // 耗时:0.5834
# Epoch :34 // train_loss:2.6072 // 耗时:0.6289
# Epoch :35 // train_loss:2.7102 // 耗时:0.7699
# Epoch :36 // train_loss:2.6497 // 耗时:0.7770
# Epoch :37 // train_loss:2.8964 // 耗时:0.7465
# Epoch :38 // train_loss:2.5128 // 耗时:0.7518
# Epoch :39 // train_loss:2.6373 // 耗时:0.7324
# Epoch :40 // train_loss:2.6311 // 耗时:0.7216
# Epoch :41 // train_loss:2.8523 // 耗时:0.5577
# Epoch :42 // train_loss:2.4751 // 耗时:0.5735
# Epoch :43 // train_loss:2.5272 // 耗时:0.5648
# Epoch :44 // train_loss:2.6659 // 耗时:0.5478
# Epoch :45 // train_loss:2.8391 // 耗时:0.6223
# Epoch :46 // train_loss:2.6325 // 耗时:0.5586
# Epoch :47 // train_loss:2.6335 // 耗时:0.5807
# Epoch :48 // train_loss:2.6234 // 耗时:0.5435
# Epoch :49 // train_loss:2.5204 // 耗时:0.5477
# Epoch :50 // train_loss:2.6308 // 耗时:0.5482
# Epoch :51 // train_loss:2.6960 // 耗时:0.6180
# Epoch :52 // train_loss:2.6062 // 耗时:0.5825
# Epoch :53 // train_loss:2.5625 // 耗时:0.5422
# Epoch :54 // train_loss:2.6250 // 耗时:0.5665
# Epoch :55 // train_loss:2.6417 // 耗时:0.5444
# Epoch :56 // train_loss:2.6490 // 耗时:0.5620
# Epoch :57 // train_loss:2.5759 // 耗时:0.5884
# Epoch :58 // train_loss:2.5989 // 耗时:0.5685
# Epoch :59 // train_loss:2.6273 // 耗时:0.5725
# Epoch :60 // train_loss:2.5301 // 耗时:0.5516
# Epoch :61 // train_loss:2.6045 // 耗时:0.5755
# Epoch :62 // train_loss:2.6005 // 耗时:0.5565
# Epoch :63 // train_loss:2.7977 // 耗时:0.5695
# Epoch :64 // train_loss:2.4728 // 耗时:0.5399
# Epoch :65 // train_loss:2.5844 // 耗时:0.5745
# Epoch :66 // train_loss:2.6359 // 耗时:0.5492
# Epoch :67 // train_loss:2.7532 // 耗时:0.5814
# Epoch :68 // train_loss:2.6500 // 耗时:0.5663
# Epoch :69 // train_loss:2.7071 // 耗时:0.5860
# Epoch :70 // train_loss:2.6387 // 耗时:0.5820
# Epoch :71 // train_loss:2.5576 // 耗时:0.5441
# Epoch :72 // train_loss:2.5768 // 耗时:0.5611
# Epoch :73 // train_loss:2.6963 // 耗时:0.5391
# Epoch :74 // train_loss:2.4630 // 耗时:0.5884
# Epoch :75 // train_loss:2.5516 // 耗时:0.5595
# Epoch :76 // train_loss:2.6854 // 耗时:0.5465
# Epoch :77 // train_loss:2.5223 // 耗时:0.5721
# Epoch :78 // train_loss:2.4897 // 耗时:0.5610
# Epoch :79 // train_loss:2.6049 // 耗时:0.5595
# Epoch :80 // train_loss:2.6220 // 耗时:0.5516
# Epoch :81 // train_loss:2.5325 // 耗时:0.6161
# Epoch :82 // train_loss:2.2307 // 耗时:0.5625
# Epoch :83 // train_loss:2.6044 // 耗时:0.5441
# Epoch :84 // train_loss:2.8300 // 耗时:0.5805
# Epoch :85 // train_loss:2.7243 // 耗时:0.5490
# Epoch :86 // train_loss:2.5155 // 耗时:0.5545
# Epoch :87 // train_loss:2.4951 // 耗时:0.5559
# Epoch :88 // train_loss:2.6393 // 耗时:0.5924
# Epoch :89 // train_loss:2.6553 // 耗时:0.5658
# Epoch :90 // train_loss:2.6214 // 耗时:0.5628
# Epoch :91 // train_loss:2.6003 // 耗时:0.5598
# Epoch :92 // train_loss:2.7879 // 耗时:0.5775
# Epoch :93 // train_loss:2.7083 // 耗时:0.5938
# Epoch :94 // train_loss:2.4677 // 耗时:0.5496
# Epoch :95 // train_loss:2.4801 // 耗时:0.5680
# Epoch :96 // train_loss:2.5546 // 耗时:0.5506
# Epoch :97 // train_loss:2.5501 // 耗时:0.5615
# Epoch :98 // train_loss:2.5310 // 耗时:0.5525
# Epoch :99 // train_loss:2.5860 // 耗时:0.5451
# Encoded.shape: torch.Size([8, 5])
# Epoch :0 // train_loss:10.0102 // 耗时:0.6134
# Epoch :1 // train_loss:5.6384 // 耗时:0.5544
# Epoch :2 // train_loss:3.7473 // 耗时:0.5775
# Epoch :3 // train_loss:3.0691 // 耗时:0.5844
# Epoch :4 // train_loss:2.8365 // 耗时:0.5740
# Epoch :5 // train_loss:2.7613 // 耗时:0.5864
# Epoch :6 // train_loss:2.8432 // 耗时:0.5545
# Epoch :7 // train_loss:2.6338 // 耗时:0.5788
# Epoch :8 // train_loss:2.5771 // 耗时:0.5521
# Epoch :9 // train_loss:2.6299 // 耗时:0.5595
# Epoch :10 // train_loss:2.6444 // 耗时:0.5612
# Epoch :11 // train_loss:2.6419 // 耗时:0.5545
# Epoch :12 // train_loss:2.6287 // 耗时:0.5814
# Epoch :13 // train_loss:2.6771 // 耗时:0.5800
# Epoch :14 // train_loss:2.5871 // 耗时:0.5765
# Epoch :15 // train_loss:2.7448 // 耗时:0.5445
# Epoch :16 // train_loss:2.8491 // 耗时:0.6089
# Epoch :17 // train_loss:2.7028 // 耗时:0.5625
# Epoch :18 // train_loss:2.6817 // 耗时:0.5806
# Epoch :19 // train_loss:2.8782 // 耗时:0.5785
# Epoch :20 // train_loss:2.6249 // 耗时:0.5715
# Epoch :21 // train_loss:2.8018 // 耗时:0.5480
# Epoch :22 // train_loss:2.8983 // 耗时:0.5534
# Epoch :23 // train_loss:2.7248 // 耗时:0.5898
# Epoch :24 // train_loss:2.7799 // 耗时:0.5525
# Epoch :25 // train_loss:2.6316 // 耗时:0.5642
# Epoch :26 // train_loss:2.7224 // 耗时:0.5670
# Epoch :27 // train_loss:2.7749 // 耗时:0.5805
# Epoch :28 // train_loss:2.6755 // 耗时:0.5907
# Epoch :29 // train_loss:2.5702 // 耗时:0.5406
# Epoch :30 // train_loss:2.6732 // 耗时:0.5927
# Epoch :31 // train_loss:2.5984 // 耗时:0.5531
# Epoch :32 // train_loss:2.6181 // 耗时:0.5814
# Epoch :33 // train_loss:2.6539 // 耗时:0.5690
# Epoch :34 // train_loss:2.5720 // 耗时:0.5595
# Epoch :35 // train_loss:2.5506 // 耗时:0.5755
# Epoch :36 // train_loss:2.8785 // 耗时:0.5504
# Epoch :37 // train_loss:2.6270 // 耗时:0.5563
# Epoch :38 // train_loss:2.5910 // 耗时:0.5639
# Epoch :39 // train_loss:2.6523 // 耗时:0.6050
# Epoch :40 // train_loss:2.8382 // 耗时:0.5894
# Epoch :41 // train_loss:2.7341 // 耗时:0.5690
# Epoch :42 // train_loss:2.6639 // 耗时:0.5691
# Epoch :43 // train_loss:2.6349 // 耗时:0.5500
# Epoch :44 // train_loss:2.7762 // 耗时:0.5630
# Epoch :45 // train_loss:2.5223 // 耗时:0.5506
# Epoch :46 // train_loss:2.6966 // 耗时:0.5834
# Epoch :47 // train_loss:2.9352 // 耗时:0.5645
# Epoch :48 // train_loss:2.5747 // 耗时:0.5685
# Epoch :49 // train_loss:2.6581 // 耗时:0.5585
# Epoch :50 // train_loss:2.5710 // 耗时:0.5412
# Epoch :51 // train_loss:2.7984 // 耗时:0.6385
# Epoch :52 // train_loss:2.7042 // 耗时:0.5844
# Epoch :53 // train_loss:2.6381 // 耗时:0.5718
# Epoch :54 // train_loss:2.7702 // 耗时:0.5685
# Epoch :55 // train_loss:2.6023 // 耗时:0.5535
# Epoch :56 // train_loss:2.6768 // 耗时:0.5540
# Epoch :57 // train_loss:2.6642 // 耗时:0.5494
# Epoch :58 // train_loss:2.5936 // 耗时:0.5994
# Epoch :59 // train_loss:2.6944 // 耗时:0.5441
# Epoch :60 // train_loss:2.7006 // 耗时:0.5735
# Epoch :61 // train_loss:2.5458 // 耗时:0.5685
# Epoch :62 // train_loss:2.5633 // 耗时:0.5511
# Epoch :63 // train_loss:2.6251 // 耗时:0.5525
# Epoch :64 // train_loss:2.4893 // 耗时:0.5680
# Epoch :65 // train_loss:2.6458 // 耗时:0.6075
# Epoch :66 // train_loss:2.5070 // 耗时:0.5565
# Epoch :67 // train_loss:2.5765 // 耗时:0.5795
# Epoch :68 // train_loss:2.6232 // 耗时:0.5820
# Epoch :69 // train_loss:2.7516 // 耗时:0.5575
# Epoch :70 // train_loss:2.5233 // 耗时:0.5713
# Epoch :71 // train_loss:2.5149 // 耗时:0.5501
# Epoch :72 // train_loss:2.6679 // 耗时:0.5465
# Epoch :73 // train_loss:2.5176 // 耗时:0.5530
# Epoch :74 // train_loss:2.6126 // 耗时:0.5924
# Epoch :75 // train_loss:2.5862 // 耗时:0.5626
# Epoch :76 // train_loss:2.4585 // 耗时:0.5736
# Epoch :77 // train_loss:2.6424 // 耗时:0.5755
# Epoch :78 // train_loss:2.6834 // 耗时:0.5515
# Epoch :79 // train_loss:2.5243 // 耗时:0.5722
# Epoch :80 // train_loss:2.5124 // 耗时:0.5515
# Epoch :81 // train_loss:2.3985 // 耗时:0.5660
# Epoch :82 // train_loss:2.3985 // 耗时:0.5546
# Epoch :83 // train_loss:2.6450 // 耗时:0.5710
# Epoch :84 // train_loss:2.5084 // 耗时:0.5904
# Epoch :85 // train_loss:2.5237 // 耗时:0.5570
# Epoch :86 // train_loss:2.5598 // 耗时:0.5685
# Epoch :87 // train_loss:2.5257 // 耗时:0.5650
# Epoch :88 // train_loss:2.6003 // 耗时:0.5401
# Epoch :89 // train_loss:2.7064 // 耗时:0.5470
# Epoch :90 // train_loss:2.5972 // 耗时:0.5956
# Epoch :91 // train_loss:2.6015 // 耗时:0.5794
# Epoch :92 // train_loss:2.6131 // 耗时:0.5466
# Epoch :93 // train_loss:2.5329 // 耗时:0.5714
# Epoch :94 // train_loss:2.5316 // 耗时:0.5515
# Epoch :95 // train_loss:2.5374 // 耗时:0.5823
# Epoch :96 // train_loss:2.5361 // 耗时:0.5517
# Epoch :97 // train_loss:2.5626 // 耗时:0.5824
# Epoch :98 // train_loss:2.5673 // 耗时:0.5600
# Epoch :99 // train_loss:2.5975 // 耗时:0.5567
# Encoded.shape: torch.Size([8, 10])
# Epoch :0 // train_loss:9.3496 // 耗时:0.5824
# Epoch :1 // train_loss:4.7368 // 耗时:0.5755
# Epoch :2 // train_loss:3.2698 // 耗时:0.6353
# Epoch :3 // train_loss:2.8506 // 耗时:0.5629
# Epoch :4 // train_loss:2.8328 // 耗时:0.5779
# Epoch :5 // train_loss:2.7215 // 耗时:0.6159
# Epoch :6 // train_loss:2.8624 // 耗时:0.5660
# Epoch :7 // train_loss:2.8531 // 耗时:0.5855
# Epoch :8 // train_loss:2.7661 // 耗时:0.5785
# Epoch :9 // train_loss:2.6960 // 耗时:0.5997
# Epoch :10 // train_loss:2.7564 // 耗时:0.5711
# Epoch :11 // train_loss:2.7236 // 耗时:0.5695
# Epoch :12 // train_loss:2.7374 // 耗时:0.6230
# Epoch :13 // train_loss:2.8040 // 耗时:0.5650
# Epoch :14 // train_loss:2.8317 // 耗时:0.5825
# Epoch :15 // train_loss:2.9116 // 耗时:0.5741
# Epoch :16 // train_loss:2.4981 // 耗时:0.6144
# Epoch :17 // train_loss:2.8163 // 耗时:0.5904
# Epoch :18 // train_loss:2.6835 // 耗时:0.5809
# Epoch :19 // train_loss:2.6676 // 耗时:0.6463
# Epoch :20 // train_loss:2.6234 // 耗时:0.5845
# Epoch :21 // train_loss:2.8334 // 耗时:0.5899
# Epoch :22 // train_loss:2.7170 // 耗时:0.6358
# Epoch :23 // train_loss:2.9370 // 耗时:0.5795
# Epoch :24 // train_loss:2.7999 // 耗时:0.5855
# Epoch :25 // train_loss:2.7301 // 耗时:0.5888
# Epoch :26 // train_loss:2.6935 // 耗时:0.6274
# Epoch :27 // train_loss:2.5967 // 耗时:0.6014
# Epoch :28 // train_loss:2.6219 // 耗时:0.5775
# Epoch :29 // train_loss:2.7561 // 耗时:0.5884
# Epoch :30 // train_loss:2.5629 // 耗时:0.5665
# Epoch :31 // train_loss:2.7583 // 耗时:0.5703
# Epoch :32 // train_loss:2.6647 // 耗时:0.6009
# Epoch :33 // train_loss:2.7716 // 耗时:0.5776
# Epoch :34 // train_loss:2.7731 // 耗时:0.5854
# Epoch :35 // train_loss:2.6621 // 耗时:0.5884
# Epoch :36 // train_loss:2.8515 // 耗时:0.6157
# Epoch :37 // train_loss:2.8347 // 耗时:0.5655
# Epoch :38 // train_loss:2.6533 // 耗时:0.5726
# Epoch :39 // train_loss:2.6834 // 耗时:0.6104
# Epoch :40 // train_loss:2.8928 // 耗时:0.5866
# Epoch :41 // train_loss:2.7770 // 耗时:0.6165
# Epoch :42 // train_loss:2.6514 // 耗时:0.7261
# Epoch :43 // train_loss:2.7021 // 耗时:0.7580
# Epoch :44 // train_loss:2.7824 // 耗时:0.7807
# Epoch :45 // train_loss:2.5271 // 耗时:0.8334
# Epoch :46 // train_loss:2.7350 // 耗时:0.7714
# Epoch :47 // train_loss:2.5195 // 耗时:0.7192
# Epoch :48 // train_loss:2.5771 // 耗时:0.5717
# Epoch :49 // train_loss:2.5621 // 耗时:0.5971
# Epoch :50 // train_loss:2.5687 // 耗时:0.5857
# Epoch :51 // train_loss:2.5915 // 耗时:0.5984
# Epoch :52 // train_loss:2.6326 // 耗时:0.5655
# Epoch :53 // train_loss:2.6836 // 耗时:0.6019
# Epoch :54 // train_loss:2.6298 // 耗时:0.5710
# Epoch :55 // train_loss:2.5814 // 耗时:0.5600
# Epoch :56 // train_loss:2.5882 // 耗时:0.6169
# Epoch :57 // train_loss:2.6333 // 耗时:0.5937
# Epoch :58 // train_loss:2.6363 // 耗时:0.6097
# Epoch :59 // train_loss:2.6516 // 耗时:0.5914
# Epoch :60 // train_loss:2.6402 // 耗时:0.5700
# Epoch :61 // train_loss:2.5070 // 耗时:0.5770
# Epoch :62 // train_loss:2.3750 // 耗时:0.5655
# Epoch :63 // train_loss:2.5592 // 耗时:0.6059
# Epoch :64 // train_loss:2.5172 // 耗时:0.5891
# Epoch :65 // train_loss:2.4181 // 耗时:0.5635
# Epoch :66 // train_loss:2.6795 // 耗时:0.5907
# Epoch :67 // train_loss:2.6379 // 耗时:0.5735
# Epoch :68 // train_loss:2.5579 // 耗时:0.5997
# Epoch :69 // train_loss:2.5826 // 耗时:0.5778
# Epoch :70 // train_loss:2.6905 // 耗时:0.6014
# Epoch :71 // train_loss:2.4195 // 耗时:0.5831
# Epoch :72 // train_loss:2.7094 // 耗时:0.5864
# Epoch :73 // train_loss:2.5278 // 耗时:0.6277
# Epoch :74 // train_loss:2.5995 // 耗时:0.5979
# Epoch :75 // train_loss:2.5228 // 耗时:0.5948
# Epoch :76 // train_loss:2.5314 // 耗时:0.6039
# Epoch :77 // train_loss:2.6541 // 耗时:0.5660
# Epoch :78 // train_loss:2.4048 // 耗时:0.5918
# Epoch :79 // train_loss:2.5605 // 耗时:0.5720
# Epoch :80 // train_loss:2.4998 // 耗时:0.5954
# Epoch :81 // train_loss:2.4616 // 耗时:0.5959
# Epoch :82 // train_loss:2.5838 // 耗时:0.5720
# Epoch :83 // train_loss:2.3656 // 耗时:0.5978
# Epoch :84 // train_loss:2.5492 // 耗时:0.5680
# Epoch :85 // train_loss:2.6834 // 耗时:0.5924
# Epoch :86 // train_loss:2.5725 // 耗时:0.5775
# Epoch :87 // train_loss:2.5195 // 耗时:0.6032
# Epoch :88 // train_loss:2.4492 // 耗时:0.6203
# Epoch :89 // train_loss:2.5531 // 耗时:0.6004
# Epoch :90 // train_loss:2.7828 // 耗时:0.6134
# Epoch :91 // train_loss:2.6858 // 耗时:0.6333
# Epoch :92 // train_loss:2.5569 // 耗时:0.6424
# Epoch :93 // train_loss:2.4817 // 耗时:0.6090
# Epoch :94 // train_loss:2.4954 // 耗时:0.6024
# Epoch :95 // train_loss:2.7096 // 耗时:0.5969
# Epoch :96 // train_loss:2.5688 // 耗时:0.6448
# Epoch :97 // train_loss:2.3346 // 耗时:0.5918
# Epoch :98 // train_loss:2.3986 // 耗时:0.5909
# Epoch :99 // train_loss:2.4926 // 耗时:0.5896
# Encoded.shape: torch.Size([8, 50])
# Epoch :0 // train_loss:8.9746 // 耗时:0.5815
# Epoch :1 // train_loss:4.4675 // 耗时:0.6154
# Epoch :2 // train_loss:3.3389 // 耗时:0.6004
# Epoch :3 // train_loss:2.8354 // 耗时:0.6547
# Epoch :4 // train_loss:2.8765 // 耗时:0.6055
# Epoch :5 // train_loss:2.7880 // 耗时:0.5804
# Epoch :6 // train_loss:2.7078 // 耗时:0.5999
# Epoch :7 // train_loss:2.7047 // 耗时:0.5834
# Epoch :8 // train_loss:2.7434 // 耗时:0.6124
# Epoch :9 // train_loss:2.7029 // 耗时:0.5863
# Epoch :10 // train_loss:2.7803 // 耗时:0.6054
# Epoch :11 // train_loss:2.4775 // 耗时:0.5914
# Epoch :12 // train_loss:2.8569 // 耗时:0.5861
# Epoch :13 // train_loss:2.7075 // 耗时:0.6453
# Epoch :14 // train_loss:2.5386 // 耗时:0.5770
# Epoch :15 // train_loss:2.7049 // 耗时:0.5964
# Epoch :16 // train_loss:2.6623 // 耗时:0.5914
# Epoch :17 // train_loss:2.7089 // 耗时:0.5877
# Epoch :18 // train_loss:2.6940 // 耗时:0.6077
# Epoch :19 // train_loss:2.6318 // 耗时:0.5984
# Epoch :20 // train_loss:2.7413 // 耗时:0.6443
# Epoch :21 // train_loss:2.6590 // 耗时:0.6343
# Epoch :22 // train_loss:2.5522 // 耗时:0.6114
# Epoch :23 // train_loss:2.5495 // 耗时:0.5994
# Epoch :24 // train_loss:2.7786 // 耗时:0.6064
# Epoch :25 // train_loss:2.5845 // 耗时:0.6259
# Epoch :26 // train_loss:2.6443 // 耗时:0.6238
# Epoch :27 // train_loss:2.9267 // 耗时:0.5949
# Epoch :28 // train_loss:2.7494 // 耗时:0.6312
# Epoch :29 // train_loss:2.8321 // 耗时:0.6039
# Epoch :30 // train_loss:2.7965 // 耗时:0.5869
# Epoch :31 // train_loss:2.7261 // 耗时:0.6034
# Epoch :32 // train_loss:2.7745 // 耗时:0.5836
# Epoch :33 // train_loss:2.6616 // 耗时:0.6100
# Epoch :34 // train_loss:2.6436 // 耗时:0.5934
# Epoch :35 // train_loss:2.6231 // 耗时:0.6106
# Epoch :36 // train_loss:2.5684 // 耗时:0.6420
# Epoch :37 // train_loss:2.5359 // 耗时:0.5814
# Epoch :38 // train_loss:2.9247 // 耗时:0.5965
# Epoch :39 // train_loss:2.8336 // 耗时:0.6240
# Epoch :40 // train_loss:2.5596 // 耗时:0.6004
# Epoch :41 // train_loss:2.6181 // 耗时:0.6083
# Epoch :42 // train_loss:2.5974 // 耗时:0.5969
# Epoch :43 // train_loss:2.4380 // 耗时:0.5894
# Epoch :44 // train_loss:2.6501 // 耗时:0.5884
# Epoch :45 // train_loss:2.6186 // 耗时:0.5904
# Epoch :46 // train_loss:2.6565 // 耗时:0.6720
# Epoch :47 // train_loss:2.6640 // 耗时:0.6019
# Epoch :48 // train_loss:2.8191 // 耗时:0.5985
# Epoch :49 // train_loss:2.7141 // 耗时:0.6036
# Epoch :50 // train_loss:2.6661 // 耗时:0.6543
# Epoch :51 // train_loss:2.6956 // 耗时:0.6329
# Epoch :52 // train_loss:2.5892 // 耗时:0.6263
# Epoch :53 // train_loss:2.5957 // 耗时:0.5859
# Epoch :54 // train_loss:2.6229 // 耗时:0.6105
# Epoch :55 // train_loss:2.3579 // 耗时:0.6114
# Epoch :56 // train_loss:2.5890 // 耗时:0.5924
# Epoch :57 // train_loss:2.5426 // 耗时:0.6802
# Epoch :58 // train_loss:2.5147 // 耗时:0.5854
# Epoch :59 // train_loss:2.6183 // 耗时:0.5994
# Epoch :60 // train_loss:2.8151 // 耗时:0.5999
# Epoch :61 // train_loss:2.5111 // 耗时:0.5884
# Epoch :62 // train_loss:2.5520 // 耗时:0.5874
# Epoch :63 // train_loss:2.4839 // 耗时:0.5914
# Epoch :64 // train_loss:2.5911 // 耗时:0.6685
# Epoch :65 // train_loss:2.6664 // 耗时:0.6215
# Epoch :66 // train_loss:2.6767 // 耗时:0.5904
# Epoch :67 // train_loss:2.5277 // 耗时:0.6635
# Epoch :68 // train_loss:2.7786 // 耗时:0.6144
# Epoch :69 // train_loss:2.7652 // 耗时:0.6622
# Epoch :70 // train_loss:2.7309 // 耗时:0.6305
# Epoch :71 // train_loss:2.7779 // 耗时:0.6562
# Epoch :72 // train_loss:2.6000 // 耗时:0.6543
# Epoch :73 // train_loss:2.5786 // 耗时:0.6537
# Epoch :74 // train_loss:2.4709 // 耗时:0.6174
# Epoch :75 // train_loss:2.6865 // 耗时:0.6293
# Epoch :76 // train_loss:2.4691 // 耗时:0.6224
# Epoch :77 // train_loss:2.8854 // 耗时:0.5859
# Epoch :78 // train_loss:2.6005 // 耗时:0.5861
# Epoch :79 // train_loss:2.8107 // 耗时:0.5994
# Epoch :80 // train_loss:2.6150 // 耗时:0.6748
# Epoch :81 // train_loss:2.6418 // 耗时:0.6682
# Epoch :82 // train_loss:2.4117 // 耗时:0.5885
# Epoch :83 // train_loss:2.5094 // 耗时:0.6144
# Epoch :84 // train_loss:2.4972 // 耗时:0.6159
# Epoch :85 // train_loss:2.6875 // 耗时:0.6173
# Epoch :86 // train_loss:2.5975 // 耗时:0.6101
# Epoch :87 // train_loss:2.5643 // 耗时:0.5914
# Epoch :88 // train_loss:2.5648 // 耗时:0.6004
# Epoch :89 // train_loss:2.6146 // 耗时:0.6084
# Epoch :90 // train_loss:2.4322 // 耗时:0.6039
# Epoch :91 // train_loss:2.5309 // 耗时:0.6380
# Epoch :92 // train_loss:2.4260 // 耗时:0.6009
# Epoch :93 // train_loss:2.5186 // 耗时:0.6298
# Epoch :94 // train_loss:2.4334 // 耗时:0.6169
# Epoch :95 // train_loss:2.4194 // 耗时:0.6213
# Epoch :96 // train_loss:2.5170 // 耗时:0.6407
# Epoch :97 // train_loss:2.3929 // 耗时:0.6210
# Epoch :98 // train_loss:2.5081 // 耗时:0.6014
# Epoch :99 // train_loss:2.6207 // 耗时:0.6269
# Encoded.shape: torch.Size([8, 100])
# Training finished

# %% [markdown]
# ### Visualization and analysis

# %%
# T-SNE & PCA Plot of Counts Data
tsne_data = TSNE(n_components=2).fit_transform(dataset)
plt.scatter(tsne_data[:,0],tsne_data[:,1],c=labels,s=3)
plt.title('data_tsne')
plt.show()

pca = PCA(n_components=2)
pca_data = pca.fit_transform(dataset)
plt.scatter(pca_data[:,0],pca_data[:,1],c=labels,s=3)
plt.title('data_pca')
plt.show()

# %%
'''
Fill the ? in the following parts, i.e., specify the 'ncoded_data'and 'econstructions'
'''
# Out:
# "\nFill the ? in the following parts, i.e., specify the 'ncoded_data'and 'econstructions'\n"

# %%
def plot_en(encoded_data):
    # T-SNE & PCA Plot of Encodings
    #####################################################
    encoded_data = encoded_data # np.array
    #####################################################

    tsne_latent = TSNE(n_components=2).fit_transform(encoded_data)
    plt.scatter(tsne_latent[:,0],tsne_latent[:,1],c=labels,s=3)
    plt.title('encoded_tsne')
    plt.show()

    pca = PCA(n_components=2)
    pca_data = pca.fit_transform(encoded_data)
    plt.scatter(pca_data[:,0],pca_data[:,1],c=labels,s=3)
    plt.title('encoded_pca')
    plt.show()
    
    
    
encoded0, decoded0 = model0(torch.tensor(dataset))
encoded1, decoded1 = model1(torch.tensor(dataset))
encoded2, decoded2 = model2(torch.tensor(dataset))
encoded3, decoded3 = model3(torch.tensor(dataset))




plot_en(encoded0.detach().numpy())
plot_en(encoded1.detach().numpy())
plot_en(encoded2.detach().numpy())
plot_en(encoded3.detach().numpy())

# %%
def plot_de(reconstructions):
    # T-SNE & PCA Plot of Reconstructions
    #####################################################
    reconstructions= reconstructions
    #####################################################
    tsne_latent = TSNE(n_components=2).fit_transform(reconstructions)
    plt.scatter(tsne_latent[:,0],tsne_latent[:,1],c=labels,s=3)
    plt.title('reconstructed_tsne')
    plt.show()

    pca = PCA(n_components=2)
    pca_data = pca.fit_transform(reconstructions)
    plt.scatter(pca_data[:,0],pca_data[:,1],c=labels,s=3)
    plt.title('reconstructed_pca')
    plt.show()
plot_de(decoded0.detach().numpy())
plot_de(decoded1.detach().numpy())
plot_de(decoded2.detach().numpy())
plot_de(decoded3.detach().numpy())

# %%
#相比于原始数据，重建的都混叠在一起了
#latent_size越大时，encode_tsne数据越混叠
#latent_size越大时，encode_pca数据越混叠
#latent_size越大时，decode_tsne数据越混叠
#latent_size越大时，decode_pca数据越混叠
