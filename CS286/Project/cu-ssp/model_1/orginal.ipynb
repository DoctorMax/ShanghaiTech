# %%
"""
Cascaded Convolution Model

- Pranav Shrestha (ps2958)
- Jeffrey Wan (jw3468)

"""

import pickle
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Model, Input
from keras.layers import Embedding, Dense, TimeDistributed, Concatenate, BatchNormalization
from keras.layers import Bidirectional, Activation, Dropout, GRU, Conv1D

from sklearn.model_selection import train_test_split, KFold
from keras.metrics import categorical_accuracy
from keras import backend as K
from keras.regularizers import l1, l2
import tensorflow as tf

import os

os.environ['CUDA_VISIBLE_DEVICES'] = '/gpu:0'



### Data Retrieval
# cb6133         = np.load("../data/cb6133.npy")
cb6133filtered = np.load("../data/cullpdb+profile_6133_filtered.npy.gz")
cb513          = np.load("../data/cb513+profile_split1.npy.gz")

print()
# print(cb6133.shape)
print(cb6133filtered.shape)
print(cb513.shape)

maxlen_seq = r = 700 # protein residues padded to 700
f = 57  # number of features for each residue

residue_list = list('ACEDGFIHKMLNQPSRTWVYX') + ['NoSeq']
q8_list      = list('LBEGIHST') + ['NoSeq']

columns = ["id", "len", "input", "profiles", "expected"]

def get_data(arr, bounds=None):
    
    if bounds is None: bounds = range(len(arr))
    
    data = [None for i in bounds]
    for i in bounds:
        seq, q8, profiles = '', '', []
        for j in range(r):
            jf = j*f
            
            # Residue convert from one-hot to decoded
            residue_onehot = arr[i,jf+0:jf+22]
            residue = residue_list[np.argmax(residue_onehot)]

            # Q8 one-hot encoded to decoded structure symbol
            residue_q8_onehot = arr[i,jf+22:jf+31]
            residue_q8 = q8_list[np.argmax(residue_q8_onehot)]

            if residue == 'NoSeq': break      # terminating sequence symbol

            nc_terminals = arr[i,jf+31:jf+33] # nc_terminals = [0. 0.]
            sa = arr[i,jf+33:jf+35]           # sa = [0. 0.]
            profile = arr[i,jf+35:jf+57]      # profile features
            
            seq += residue # concat residues into amino acid sequence
            q8  += residue_q8 # concat secondary structure into secondary structure sequence
            profiles.append(profile)
        
        data[i] = [str(i+1), len(seq), seq, np.array(profiles), q8]
    
    return pd.DataFrame(data, columns=columns)

### Train-test Specification
train_df = get_data(cb6133filtered)
test_df  = get_data(cb513)

# The custom accuracy metric used for this task
def myaccuracy(y_true, y_pred):
    y = tf.argmax(y_true, axis =- 1)
    y_ = tf.argmax(y_pred, axis =- 1)
    mask = tf.greater(y, 0)
    return K.cast(K.equal(tf.boolean_mask(y, mask), tf.boolean_mask(y_, mask)), K.floatx())

# Maps the sequence to a one-hot encoding
def onehot_to_seq(oh_seq, index):
    s = ''
    for o in oh_seq:
        i = np.argmax(o)
        if i != 0:
            s += index[i]
        else:
            break
    return s

def seq2onehot(seq, n):
    out = np.zeros((len(seq), maxlen_seq, n))
    for i in range(len(seq)):
        for j in range(maxlen_seq):
            out[i, j, seq[i, j]] = 1
    return out

# Computes and returns the n-grams of a particualr sequence, defaults to trigrams
def seq2ngrams(seqs, n = 1):
    return np.array([[seq[i : i + n] for i in range(len(seq))] for seq in seqs])

# Loading and converting the inputs to trigrams
train_input_seqs, train_target_seqs = \
    train_df[['input', 'expected']][(train_df.len.astype(int) <= maxlen_seq)].values.T
train_input_grams = seq2ngrams(train_input_seqs)

# Same for test
test_input_seqs = test_df['input'].values.T
test_input_grams = seq2ngrams(test_input_seqs)

# Initializing and defining the tokenizer encoders and decoders based on the train set
tokenizer_encoder = Tokenizer()
tokenizer_encoder.fit_on_texts(train_input_grams)
tokenizer_decoder = Tokenizer(char_level = True)
tokenizer_decoder.fit_on_texts(train_target_seqs)

# Using the tokenizer to encode and decode the sequences for use in training
# Inputs
train_input_data = tokenizer_encoder.texts_to_sequences(train_input_grams)
train_input_data = sequence.pad_sequences(train_input_data,
                                          maxlen = maxlen_seq, padding='post')

# Targets
train_target_data = tokenizer_decoder.texts_to_sequences(train_target_seqs)
train_target_data = sequence.pad_sequences(train_target_data,
                                           maxlen = maxlen_seq, padding='post')
train_target_data = to_categorical(train_target_data)

# Use the same tokenizer defined on train for tokenization of test
test_input_data = tokenizer_encoder.texts_to_sequences(test_input_grams)
test_input_data = sequence.pad_sequences(test_input_data,
                                         maxlen = maxlen_seq, padding='post')

# Computing the number of words and number of tags for the keras model
n_words = len(tokenizer_encoder.word_index) + 1
n_tags = len(tokenizer_decoder.word_index) + 1

train_input_data_alt = train_input_data
train_input_data = seq2onehot(train_input_data, n_words)
train_profiles = train_df.profiles.values

test_input_data_alt = test_input_data
test_input_data = seq2onehot(test_input_data, n_words)
test_profiles = test_df.profiles.values

train_profiles_np = np.zeros((len(train_profiles), maxlen_seq, 22))
for i, profile in enumerate(train_profiles):
    for j in range(profile.shape[0]):
        for k in range(profile.shape[1]):
            train_profiles_np[i, j, k] = profile[j, k]

test_profiles_np = np.zeros((len(test_profiles), maxlen_seq, 22))
for i, profile in enumerate(test_profiles):
    for j in range(profile.shape[0]):
        for k in range(profile.shape[1]):
            test_profiles_np[i, j, k] = profile[j, k]

def decode_results(y_, reverse_decoder_index):
    print("prediction: " + str(onehot_to_seq(y_, reverse_decoder_index).upper()))
    return str(onehot_to_seq(y_, reverse_decoder_index).upper())

def run_test(_model, data1, data2, data3, csv_name, npy_name):
    reverse_decoder_index = {value:key for key,value in tokenizer_decoder.word_index.items()}
    reverse_encoder_index = {value:key for key,value in tokenizer_encoder.word_index.items()}
    
    # Get predictions using our model
    y_test_pred = _model.predict([data1, data2, data3])

    decoded_y_pred = []
    for i in range(len(test_input_data)):
        res = decode_results(y_test_pred[i], reverse_decoder_index)
        decoded_y_pred.append(res)

    # Set Columns
    out_df = pd.DataFrame()
    out_df["id"] = test_df.id.values
    out_df["expected"] = decoded_y_pred

    # Save results
    with open(csv_name, "w") as f:
        out_df.to_csv(f, index=False)

    np.save(npy_name, y_test_pred)


""" Run below for a single run """
def train(X_train, y_train, X_val=None, y_val=None):
    """
    Main Training function with the following properties:
        Optimizer - Nadam
        Loss function - Categorical Crossentropy
        Batch Size - 128 (any more will exceed Collab GPU RAM)
        Epochs - 50
    """
    model = CNN_BIGRU()
    model.compile(
        optimizer="Nadam",
        loss = "categorical_crossentropy",
        metrics = ["accuracy", myaccuracy])
    
    if X_val is not None and y_val is not None:
        history = model.fit( X_train, y_train,
            batch_size = 128, epochs = 100,
            validation_data = (X_val, y_val))
    else:
        history = model.fit( X_train, y_train,
            batch_size = 128, epochs = 100)

    return history, model

""" Build model """
def conv_block(x, activation=True, batch_norm=True, drop_out=True, res=True):
    cnn = Conv1D(64, 11, padding="same")(x)
    if activation: cnn = TimeDistributed(Activation("relu"))(cnn)
    if batch_norm: cnn = TimeDistributed(BatchNormalization())(cnn)
    if drop_out:   cnn = TimeDistributed(Dropout(0.5))(cnn)
    if res:        cnn = Concatenate(axis=-1)([x, cnn])
    
    return cnn

def super_conv_block(x):
    c3 = Conv1D(32, 1, padding="same")(x)
    c3 = TimeDistributed(Activation("relu"))(c3)
    c3 = TimeDistributed(BatchNormalization())(c3)
    
    c7 = Conv1D(64, 3, padding="same")(x)
    c7 = TimeDistributed(Activation("relu"))(c7)
    c7 = TimeDistributed(BatchNormalization())(c7)
    
    c11 = Conv1D(128, 5, padding="same")(x)
    c11 = TimeDistributed(Activation("relu"))(c11)
    c11 = TimeDistributed(BatchNormalization())(c11)
    
    x = Concatenate(axis=-1)([x, c3, c7, c11])
    x = TimeDistributed(Dropout(0.5))(x)
    return x

def CNN_BIGRU():
    # Inp is one-hot encoded version of inp_alt
    inp          = Input(shape=(maxlen_seq, n_words))
    inp_alt      = Input(shape=(maxlen_seq,))
    inp_profiles = Input(shape=(maxlen_seq, 22))

    # Concatenate embedded and unembedded input
    x_emb = Embedding(input_dim=n_words, output_dim=64, 
                      input_length=maxlen_seq)(inp_alt)
    x = Concatenate(axis=-1)([inp, x_emb, inp_profiles])

    x = super_conv_block(x)
    x = conv_block(x)
    x = super_conv_block(x)
    x = conv_block(x)
    x = super_conv_block(x)
    x = conv_block(x)

    x = Bidirectional(GRU(units = 256, return_sequences = True, recurrent_regularizer=l2(0.2)))(x)
    x = TimeDistributed(Dropout(0.5))(x)
    x = TimeDistributed(Dense(256, activation = "relu"))(x)
    x = TimeDistributed(Dropout(0.5))(x)
    
    y = TimeDistributed(Dense(n_tags, activation = "softmax"))(x)
    
    model = Model([inp, inp_alt, inp_profiles], y)
    
    return model

X_train = [train_input_data, train_input_data_alt, train_profiles_np]
y_train = train_target_data

history, model = train(X_train, y_train)

# Save the model as a JSON format
model.save_weights("cb513_weights_1.h5")
with open("model_1.json", "w") as json_file:
    json_file.write(model.to_json())

# Save training history for parsing
with open("history_1.pkl", "wb") as hist_file:
    pickle.dump(history.history, hist_file)

# Predict on test dataset and save the output
run_test(model,
    test_input_data[:],
    test_input_data_alt[:],
    test_profiles_np[:],
    "cb513_test_1.csv", "cb513_test_prob_1.npy")
""" End single run """
# Out:
# (5534, 39900)
# (514, 39900)
# Epoch 1/100
# 44/44 [==============================] - 1340s 30s/step - loss: 51.4307 - accuracy: 0.7974 - myaccuracy: 0.3892
# Epoch 2/100
# 44/44 [==============================] - 1987s 45s/step - loss: 8.2670 - accuracy: 0.8694 - myaccuracy: 0.5732
# Epoch 3/100
# 44/44 [==============================] - 2294s 52s/step - loss: 1.5804 - accuracy: 0.8812 - myaccuracy: 0.6116
# Epoch 4/100
# 44/44 [==============================] - 2309s 52s/step - loss: 0.5235 - accuracy: 0.8889 - myaccuracy: 0.6367
# Epoch 5/100
# 44/44 [==============================] - 2346s 53s/step - loss: 0.3419 - accuracy: 0.8931 - myaccuracy: 0.6502
# Epoch 6/100
# 44/44 [==============================] - 2387s 54s/step - loss: 0.3050 - accuracy: 0.8956 - myaccuracy: 0.6585
# Epoch 7/100
# 44/44 [==============================] - 2366s 54s/step - loss: 0.2942 - accuracy: 0.8973 - myaccuracy: 0.6638
# Epoch 8/100
# 44/44 [==============================] - 2352s 53s/step - loss: 0.2874 - accuracy: 0.8989 - myaccuracy: 0.6691
# Epoch 9/100
# 44/44 [==============================] - 2353s 53s/step - loss: 0.2859 - accuracy: 0.8993 - myaccuracy: 0.6705
# Epoch 10/100
# 44/44 [==============================] - 2356s 54s/step - loss: 0.2822 - accuracy: 0.9003 - myaccuracy: 0.6735
# Epoch 11/100
# 44/44 [==============================] - 2355s 54s/step - loss: 0.2780 - accuracy: 0.9015 - myaccuracy: 0.6777
# Epoch 12/100
# 44/44 [==============================] - 2353s 53s/step - loss: 0.2758 - accuracy: 0.9021 - myaccuracy: 0.6795
# Epoch 13/100
# 44/44 [==============================] - 2351s 53s/step - loss: 0.2738 - accuracy: 0.9027 - myaccuracy: 0.6814
# Epoch 14/100
# 44/44 [==============================] - 2348s 53s/step - loss: 0.2720 - accuracy: 0.9032 - myaccuracy: 0.6831
# Epoch 15/100
# 44/44 [==============================] - 2351s 53s/step - loss: 0.2704 - accuracy: 0.9038 - myaccuracy: 0.6851
# Epoch 16/100
# 44/44 [==============================] - 2352s 53s/step - loss: 0.2677 - accuracy: 0.9045 - myaccuracy: 0.6873
# Epoch 17/100
# 44/44 [==============================] - 2353s 53s/step - loss: 0.2657 - accuracy: 0.9049 - myaccuracy: 0.6887
# Epoch 18/100
# 44/44 [==============================] - 2359s 54s/step - loss: 0.2644 - accuracy: 0.9054 - myaccuracy: 0.6904
# Epoch 19/100
# 44/44 [==============================] - 2352s 53s/step - loss: 0.2631 - accuracy: 0.9057 - myaccuracy: 0.6914
# Epoch 20/100
# 44/44 [==============================] - 2352s 53s/step - loss: 0.2615 - accuracy: 0.9062 - myaccuracy: 0.6928
# Epoch 21/100
# 44/44 [==============================] - 2349s 53s/step - loss: 0.2599 - accuracy: 0.9068 - myaccuracy: 0.6949
# Epoch 22/100
# 44/44 [==============================] - 2352s 53s/step - loss: 0.2585 - accuracy: 0.9072 - myaccuracy: 0.6961
# Epoch 23/100
# 44/44 [==============================] - 2351s 53s/step - loss: 0.2578 - accuracy: 0.9075 - myaccuracy: 0.6972
# Epoch 24/100
# 44/44 [==============================] - 2358s 54s/step - loss: 0.2575 - accuracy: 0.9076 - myaccuracy: 0.6977
# Epoch 25/100
# 44/44 [==============================] - 2361s 54s/step - loss: 0.2557 - accuracy: 0.9081 - myaccuracy: 0.6993
# Epoch 26/100
# 44/44 [==============================] - 2359s 54s/step - loss: 0.2542 - accuracy: 0.9088 - myaccuracy: 0.7014
# Epoch 27/100
# 44/44 [==============================] - 2357s 54s/step - loss: 0.2528 - accuracy: 0.9091 - myaccuracy: 0.7025
# Epoch 28/100
# 44/44 [==============================] - 2360s 54s/step - loss: 0.2527 - accuracy: 0.9093 - myaccuracy: 0.7030
# Epoch 29/100
# 44/44 [==============================] - 2362s 54s/step - loss: 0.2510 - accuracy: 0.9097 - myaccuracy: 0.7043
# Epoch 30/100
# 44/44 [==============================] - 2714s 62s/step - loss: 0.2508 - accuracy: 0.9098 - myaccuracy: 0.7048
# Epoch 31/100
# 44/44 [==============================] - 2925s 66s/step - loss: 0.2497 - accuracy: 0.9101 - myaccuracy: 0.7058
# Epoch 32/100
# 44/44 [==============================] - 2927s 67s/step - loss: 0.2490 - accuracy: 0.9104 - myaccuracy: 0.7067
# Epoch 33/100
# 44/44 [==============================] - 2924s 66s/step - loss: 0.2490 - accuracy: 0.9105 - myaccuracy: 0.7072
# Epoch 34/100
# 44/44 [==============================] - 2932s 67s/step - loss: 0.2465 - accuracy: 0.9112 - myaccuracy: 0.7094
# Epoch 35/100
# 44/44 [==============================] - 2928s 67s/step - loss: 0.2467 - accuracy: 0.9111 - myaccuracy: 0.7091
# Epoch 36/100
# 44/44 [==============================] - 2931s 67s/step - loss: 0.2460 - accuracy: 0.9115 - myaccuracy: 0.7102
# Epoch 37/100
# 44/44 [==============================] - 2925s 66s/step - loss: 0.2446 - accuracy: 0.9119 - myaccuracy: 0.7115
# Epoch 38/100
# 44/44 [==============================] - 2926s 67s/step - loss: 0.2440 - accuracy: 0.9121 - myaccuracy: 0.7122
# Epoch 39/100
# 44/44 [==============================] - 2924s 66s/step - loss: 0.2435 - accuracy: 0.9123 - myaccuracy: 0.7128
# Epoch 40/100
# 44/44 [==============================] - 2928s 67s/step - loss: 0.2434 - accuracy: 0.9122 - myaccuracy: 0.7126
# Epoch 41/100
# 44/44 [==============================] - 2928s 67s/step - loss: 0.2423 - accuracy: 0.9126 - myaccuracy: 0.7140
# Epoch 42/100
# 44/44 [==============================] - 2928s 67s/step - loss: 0.2416 - accuracy: 0.9129 - myaccuracy: 0.7150
# Epoch 43/100
# 44/44 [==============================] - 2926s 67s/step - loss: 0.2418 - accuracy: 0.9129 - myaccuracy: 0.7149
# Epoch 44/100
# 44/44 [==============================] - 2925s 66s/step - loss: 0.2410 - accuracy: 0.9131 - myaccuracy: 0.7156
# Epoch 45/100
# 44/44 [==============================] - 2926s 66s/step - loss: 0.2404 - accuracy: 0.9133 - myaccuracy: 0.7162
# Epoch 46/100
# 44/44 [==============================] - 2925s 66s/step - loss: 0.2390 - accuracy: 0.9137 - myaccuracy: 0.7174
# Epoch 47/100
# 44/44 [==============================] - 2924s 66s/step - loss: 0.2383 - accuracy: 0.9140 - myaccuracy: 0.7183
# Epoch 48/100
# 44/44 [==============================] - 2922s 66s/step - loss: 0.2383 - accuracy: 0.9140 - myaccuracy: 0.7184
# Epoch 49/100
# 44/44 [==============================] - 2916s 66s/step - loss: 0.2380 - accuracy: 0.9140 - myaccuracy: 0.7186
# Epoch 50/100
# 44/44 [==============================] - 2903s 66s/step - loss: 0.2374 - accuracy: 0.9142 - myaccuracy: 0.7190
# Epoch 51/100
# 44/44 [==============================] - 2904s 66s/step - loss: 0.2369 - accuracy: 0.9144 - myaccuracy: 0.7196
# Epoch 52/100
# 44/44 [==============================] - 2907s 66s/step - loss: 0.2415 - accuracy: 0.9130 - myaccuracy: 0.7155
# Epoch 53/100
# 44/44 [==============================] - 2906s 66s/step - loss: 0.2373 - accuracy: 0.9144 - myaccuracy: 0.7199
# Epoch 54/100
# 44/44 [==============================] - 2903s 66s/step - loss: 0.2361 - accuracy: 0.9147 - myaccuracy: 0.7206
# Epoch 55/100
# 44/44 [==============================] - 2908s 66s/step - loss: 0.2351 - accuracy: 0.9149 - myaccuracy: 0.7216
# Epoch 56/100
# 44/44 [==============================] - 2906s 66s/step - loss: 0.2359 - accuracy: 0.9148 - myaccuracy: 0.7210
# Epoch 57/100
# 44/44 [==============================] - 2902s 66s/step - loss: 0.2344 - accuracy: 0.9153 - myaccuracy: 0.7227
# Epoch 58/100
# 44/44 [==============================] - 2897s 66s/step - loss: 0.2335 - accuracy: 0.9155 - myaccuracy: 0.7234
# Epoch 59/100
# 44/44 [==============================] - 2899s 66s/step - loss: 0.2337 - accuracy: 0.9155 - myaccuracy: 0.7234
# Epoch 60/100
# 44/44 [==============================] - 2900s 66s/step - loss: 0.2332 - accuracy: 0.9156 - myaccuracy: 0.7237
# Epoch 61/100
# 44/44 [==============================] - 2897s 66s/step - loss: 0.2337 - accuracy: 0.9157 - myaccuracy: 0.7240
# Epoch 62/100
# 44/44 [==============================] - 2896s 66s/step - loss: 0.2327 - accuracy: 0.9158 - myaccuracy: 0.7245
# Epoch 63/100
# 44/44 [==============================] - 2894s 66s/step - loss: 0.2324 - accuracy: 0.9160 - myaccuracy: 0.7252
# Epoch 64/100
# 44/44 [==============================] - 2899s 66s/step - loss: 0.2323 - accuracy: 0.9159 - myaccuracy: 0.7247
# Epoch 65/100
# 44/44 [==============================] - 2898s 66s/step - loss: 0.2316 - accuracy: 0.9161 - myaccuracy: 0.7254
# Epoch 66/100
# 44/44 [==============================] - 2894s 66s/step - loss: 0.2314 - accuracy: 0.9162 - myaccuracy: 0.7257
# Epoch 67/100
# 44/44 [==============================] - 2898s 66s/step - loss: 0.2309 - accuracy: 0.9164 - myaccuracy: 0.7264
# Epoch 68/100
# 44/44 [==============================] - 2900s 66s/step - loss: 0.2307 - accuracy: 0.9166 - myaccuracy: 0.7269
# Epoch 69/100
# 44/44 [==============================] - 2897s 66s/step - loss: 0.2303 - accuracy: 0.9166 - myaccuracy: 0.7269
# Epoch 70/100
# 44/44 [==============================] - 2896s 66s/step - loss: 0.2298 - accuracy: 0.9168 - myaccuracy: 0.7275
# Epoch 71/100
# 44/44 [==============================] - 2893s 66s/step - loss: 0.2295 - accuracy: 0.9168 - myaccuracy: 0.7277
# Epoch 72/100
# 44/44 [==============================] - 2896s 66s/step - loss: 0.2295 - accuracy: 0.9169 - myaccuracy: 0.7281
# Epoch 73/100
# 44/44 [==============================] - 2890s 66s/step - loss: 0.2290 - accuracy: 0.9170 - myaccuracy: 0.7283
# Epoch 74/100
# 44/44 [==============================] - 2886s 66s/step - loss: 0.2291 - accuracy: 0.9169 - myaccuracy: 0.7280
# Epoch 75/100
# 44/44 [==============================] - 2876s 65s/step - loss: 0.2287 - accuracy: 0.9172 - myaccuracy: 0.7291
# Epoch 76/100
# 44/44 [==============================] - 2877s 65s/step - loss: 0.2283 - accuracy: 0.9173 - myaccuracy: 0.7294
# Epoch 77/100
# 44/44 [==============================] - 2871s 65s/step - loss: 0.2279 - accuracy: 0.9174 - myaccuracy: 0.7295
# Epoch 78/100
# 44/44 [==============================] - 2886s 66s/step - loss: 0.2280 - accuracy: 0.9173 - myaccuracy: 0.7293
# Epoch 79/100
# 44/44 [==============================] - 2871s 65s/step - loss: 0.2271 - accuracy: 0.9177 - myaccuracy: 0.7306
# Epoch 80/100
# 44/44 [==============================] - 2866s 65s/step - loss: 0.2270 - accuracy: 0.9176 - myaccuracy: 0.7302
# Epoch 81/100
# 44/44 [==============================] - 2870s 65s/step - loss: 0.2266 - accuracy: 0.9178 - myaccuracy: 0.7310
# Epoch 82/100
# 44/44 [==============================] - 2873s 65s/step - loss: 0.2271 - accuracy: 0.9176 - myaccuracy: 0.7304
# Epoch 83/100
# 44/44 [==============================] - 2870s 65s/step - loss: 0.2261 - accuracy: 0.9181 - myaccuracy: 0.7319
# Epoch 84/100
# 44/44 [==============================] - 2869s 65s/step - loss: 0.2259 - accuracy: 0.9182 - myaccuracy: 0.7322
# Epoch 85/100
# 44/44 [==============================] - 2865s 65s/step - loss: 0.2261 - accuracy: 0.9181 - myaccuracy: 0.7319
# Epoch 86/100
# 44/44 [==============================] - 2854s 65s/step - loss: 0.2257 - accuracy: 0.9180 - myaccuracy: 0.7317
# Epoch 87/100
# 44/44 [==============================] - 2852s 65s/step - loss: 0.2250 - accuracy: 0.9185 - myaccuracy: 0.7331
# Epoch 88/100
# 44/44 [==============================] - 2849s 65s/step - loss: 0.2251 - accuracy: 0.9183 - myaccuracy: 0.7324
# Epoch 89/100
# 44/44 [==============================] - 2851s 65s/step - loss: 0.2251 - accuracy: 0.9184 - myaccuracy: 0.7328
# Epoch 90/100
# 44/44 [==============================] - 2851s 65s/step - loss: 0.2250 - accuracy: 0.9183 - myaccuracy: 0.7327
# Epoch 91/100
# 44/44 [==============================] - 2852s 65s/step - loss: 0.2246 - accuracy: 0.9184 - myaccuracy: 0.7330
# Epoch 92/100
# 44/44 [==============================] - 2852s 65s/step - loss: 0.2245 - accuracy: 0.9184 - myaccuracy: 0.7330
# Epoch 93/100
# 44/44 [==============================] - 2853s 65s/step - loss: 0.2242 - accuracy: 0.9185 - myaccuracy: 0.7332
# Epoch 94/100
# 44/44 [==============================] - 2855s 65s/step - loss: 0.2241 - accuracy: 0.9187 - myaccuracy: 0.7338
# Epoch 95/100
# 44/44 [==============================] - 2855s 65s/step - loss: 0.2241 - accuracy: 0.9186 - myaccuracy: 0.7337
# Epoch 96/100
# 44/44 [==============================] - 2857s 65s/step - loss: 0.2234 - accuracy: 0.9188 - myaccuracy: 0.7343
# Epoch 97/100
# 44/44 [==============================] - 2856s 65s/step - loss: 0.2235 - accuracy: 0.9188 - myaccuracy: 0.7341
# Epoch 98/100
# 44/44 [==============================] - 2854s 65s/step - loss: 0.2234 - accuracy: 0.9189 - myaccuracy: 0.7344
# Epoch 99/100
# 44/44 [==============================] - 2858s 65s/step - loss: 0.2232 - accuracy: 0.9189 - myaccuracy: 0.7346
# Epoch 100/100
# 44/44 [==============================] - 2859s 65s/step - loss: 0.2232 - accuracy: 0.9189 - myaccuracy: 0.7344
# prediction: LLHHHHHHHHHHHHHHHHHHHHHHHTTLLLSSLEEEELTTSLEEEEELTTSHHHHTTEEEEEEEELL
# prediction: LLEEEEELTTLLTLHHHHHHHHHHHHTTLLLEEEELLLLTTLLLHHHHHHHHHHHTLLLLTLLLLLEEELTTSLEELHHHHHHHHHL
# prediction: ...
# prediction: LLLEEELLTTTLLTTLEEEEEEETTTEEEEEEEEEELTTSLLLLGGGEEEEEELTTSLEEEEEEEEEEEEEELTTSLEEEEEELLSLLEEEEEESLTLLLTEEEEELL
# prediction: 
# prediction: LLEEEEEEEEEEEEEEETTTEEEEEEELLLTTSTTLLLLSLEEEEEETTTTLEEEEL
# prediction: LLLTTSLLLLLLLTTLLHHHHLGGGLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLHHHHHHHHHHHHTTTTTLLLTTTLTTTLLLLLLLLGGHHGGTTLLLHHHHHHHHHHHHHHHHHHHHHHSTTLLHHHHHHHHHHHHHHLGGGLLLGTGLLTTLLHHHHHHHHHHHHHHHHHHTL
# prediction: LLLTTHHHGLLHHHHHHHHHTTLSLLTLTTTLLLTTHGGHLHHHHHHHHHHTTLLLTTLTTLLLLLEELTTTTLLLLLHHHHHHHHHHHTTLSLHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHTTSSLHHGHTTSLLLLTTLHHHHHHHHHHHHHHHLHHHHHHHHHHHHHHHHTLGGGLL
# prediction: LEEEEEEEEEEEEEELTTSLEEEEEEETTSSLSLEEEELTTLEEEEEEEELLLTTLEEEEEEEGGLTTLTGGLLLLEEEELLLLTTLLEEEEEEESSTTEEEEEEETTTTTTTTLEEEEEELLLTTLLLL
# prediction: LLLLEEEEEEEEEELLSLHHHHHHHHHHSLLLLLTLLHHHHHTLLLLLLLLHHHHTLTTSLLLTTTTLTTLLLEEEEELTTLEEEEEEEEEELLTTEEEEETTEEEEEEEEEEEELLLEEESEEEELTTLEEEEEEEELSLTTSLEEEEEELLLLLTTSLLEEEEEEELLLLLLLLLLLLLLLLLLTTLHHHHHHHHHHHHHHHTL
# prediction: LTTLLHHHHHHHHHHHHHHHHHTTTLLLLLSSLLLLHHHHHHHTHHHHHGGGGLHHHHHHHHHHHHHHHHHHHHHHHTSLLLLHHHHHHHHHHHHHHHHL
# prediction: LLLLSLLLEEEEEEEEEEEETTEEEEEEEEEESSLLSSLHHHHHHTTLLTLLLSSLLLLLLLTTLLTTSLLLLLLLLLLLEEEEELTTLEEEEEEELHHHHLTTLLLLLLEEETTEEEEEEEELSSLLLTTLGGGLLLSSLLGGLEEEELTTEEEEEEEEESSTHHHHHHHHHHHHHHHHHHHHHHHHHHHHSLLLTTGGGLTTHHHHHHTLLLLL
# prediction: LLLLLLLTTLEEEEEEELLLLSTTEEEEEEEETTTTLEEEEELSSLLHHHHHHHHHHHHHHHLLLSEEEETSSTTLLLHHHHHHHHHTTLEEEELLTTLTTHHHHHHHHHHHHHHHHHHHHTTTLLLLLSSHHHHHHHHHHHHHHHHL
# prediction: LHHHHHHHHTLHHHHHHHLL
# prediction: LLTTSLLLHHHHHHHHHHHHHHHHGGHLLLHHHHHHHHHHSLHHHHHHHHHHHHHHHSSLHHHHHHHHHLSLHHHHHHHHHHHHHL
# prediction: LLHHHHHHHHHHHTTTTLLHHHHHHHHHHHLHHHHHHHHHHHHHHHSSLHHHHHHHHLLHHHHHHHHHHHTTLL
# prediction: LLLLLLTTLLHHHHHHHHHHHTLLTEEEEEELSSSTTLEEEEEEETTEEEEEEEEEETTEEEEETTEEESSHHHHHHHHHHHTTGLBLTTSLEEEESSLLL
# prediction: LEEEEEELGGGLLLESEEEEETTTLEEEEEEELTTLSLGGGLLEEEEELSHHHHHHHHHHHHHHTGGTTLSLTTLTTEEEEEEELLTTLEEEEEEEGGGLLTTLEEEEEEELTTGGGGLEEEEEEL
# prediction: LLLEEEEELHHHHHHHHTSHHHHHHHHHHHHHHHSLLLLTTLSLEEEETTLTTLLSHHHHHHHHHHHHHHHHLLEEEELHHHHHHHHHHLLLLEEEEEEEESLHHHHHHHHHHHHHHHHTTSLSEEEEEEEHHHHHHHHHTTLLLHHHHGGGLLLLTTSLEEEEEELGGGHLTTSLLLLLLLTHHHHHHHHHHHHHHHHL
# prediction: LLLLLLLLLLLLLLSTLLGGGHTTSEEEEEEELLLTEETTEEEEEEEEEETTEEEEEEEEEETTEEEEEEEEEEEELTTGLEEEEEEELLLLLLLSLLEEEEEEETTTEEEEEEEEELTTSLLEEEEEEEEESSSLLLHHHHHHHHHHHHTSTTLLGGGLEELLLLGGGLLLL
# prediction: LLLLEEEEEEETSSEEEEELSTTLEEEEEEESTSLEEEEELLLTTLLEEEEEEEEEEELTTSLEEEEEEEEESSTTEEEEEEEETLLLLTTLLEEEEEEETTEEEEEEEEEESSLLLEESSSSLEEEEEEEELLLLTTSLLLEEEHHHHHHHHHHTTLLLTSLHHHHHHHHHHHTTTEEEEEEEL
# prediction: LLTSLEEELLEEEEEELLLLTTLLLLLLTTLELLTTLEEEEEEELLLTTTSLLSSLEEEEEEEEETSSLEETTSLEEEEL
# prediction: LLLLEELSLTTTLLEEEEELLLTTTLLLLLLGLLSTTEEELLL
# prediction: LLLLLLLEEEEEEELSSEEELTTTLEEEEEEEEEETTEEEEEEEEEEEELLLSLLLTLLLLLLTTEEEEEEESEEEEEEEEEEETTEEEEEEEEEETTEEEEEEELL
# prediction: LLEEEEETTTEEEEEELTTSLEEEEEELLLHHHHHHHHHHHTTEEEEEETTTTEEEEELTTSLEEEEEELLTTEEEEEEELTTLEEEEELTTLTTEEEEELTTSLELLLLLLLTTLLEEEEEELLL
# prediction: LLLLLLEEEEEEEEESLLLLLGLLSLEEEEEEEEETEEEEELTTSLEEEEEELLHHHHHHHHHHHHTTLEEEEEEEEELTTLLELLGGGEEEEEEEELSSSSLLLEEEEEEELTTEEEEEEEEEEELLTHHHHHHTLTGTTLLEEEEEEEESLGGGLEEEEEEEEELTTEEEETTEEELLLLLLL
# prediction: 
# prediction: LLLEEEEESHHHHHHHHHHHHHHTTLLEEEEELHHHTTLHHHHHHHHHHEESLLLLSSLGGLHHHHHHHHHHHTLSEEELLLHGGGGLHHHHHHHHHTTLEEELLLHHHHHHHL
# prediction: LLLLTLSSHHHHHHHHHHHTLLEEEELLLSSHHHHHHHHHHHHHHHHHHHL
# prediction: LLHHHHHHHHHHLTTTLLLLTSEEEEEELLLSTTEEEEEGLLTTLLLLTTLHHHHHHHHHELSSHHHHHHHHHHHHHHHHHHTLLLLHHHHHHHHTLHHHHTTLLLHHHHHHHHHHHL
# prediction: LLLLEEEEEEEEEELTTLEEEEEETTEEEEEEEEEHHHHHHHHHHHTEEEEEEELLLLTTLLEEEEEEL
# prediction: LHHHHHHHHHHHHHHHHHHHL
# prediction: LEEEELTTLSSHHHHHHHHHHHHTLLGGTLSLHHHHHHHHHTTLLSLEEEEEELHHHHHHHHTHHHHHHHHHHHHHHTTTEEEEEL
# prediction: LLLHHHHHHHHHHHLLLLTTEELHHHHHHTTLLGGGSLGGGGSTTLEETLLTTLLTTSLLLLLTTLEEEEEEELLLSTLLLLTEEEELTTSEEEEESSTTTTEEEEL
# prediction: ...
# prediction: LLLLLLLLLLLTLLSLEELLTTLEEEEELTTLELLL
# prediction: LLLLLLHHHHHHHHHHHHHHTTLTTLLLLLLHHHHHHHHHHTTLHHHHHHHHHHTTTLLLTTTLLTTLLHHHHHHHHHHHHTL
# prediction: LHHHHHHHHHHHHHHHHHHL
# prediction: LLLLGGGLLHHHHHHHHHHHHHHHHHLLHHHHHHHHHHHHHHHTLTTSLLLEELLLTTLTTLHHHHHHHHHHHHHHTTLLHLLLL
# prediction: LLLLLLLLLLLEELTTTLEEEEEEEEELTTLLEEEEEEEETLLLLLTTLEEEELSSLLLL
# prediction: ...
# prediction: 
# prediction: LLLLLLLLLLHHHHHHHHHHHLLLTTLLTTHHHHHHHLGGGHHHHHHTTLLLL
# prediction: LLLEELLTTLHHHHHHHHHHHHHHHHHHTLTTEEEEEEEEEEEEEEETTEEEEEEEEEEEELLLLTLSLLLLLLLLSLGGGGGEEEEEEEEEEELTTTEEEEEEEELL
# prediction: LLLLLLLLLSLLEEEEETTEEEEEEELLLTTTLLEEEEEEEEELSSLTTLEEEEEEELTTLLEEEEEELLTTLEEEEEEEEEETTSLLLLLLLLLLEEELL
# prediction: 
# prediction: LHHHHTTLEEEEEEETTEEEEEEEETTEEEEEEEESLTTSLEEEETLLTLLLTSLEEEEEEEEETTLEEEETTSLEEEEEELTTLEEEEEEELLLL
# prediction: LLEEEEELLLLLLTTLEEEEEEESLLSSLEEEEETTEEEEEEEEEEEETTEEEEEELSLLTTLEEEEEEETTEEELLLLLEELL
# prediction: LLLEEEEEEEEEELELLTTLEEEEESLHGGGTLLLTTTLLLLLLLLLLLLSSLEEEEEEEELTTLEEEEEEEEETTTEEEEELSTTEEEEELTTLLEEEEEEEL
# prediction: LLHHHHHHHHHHHTHHHHHHHHHHHHHHHHHTTLEEEEEEEETTTLEEEEELTTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHEEEELTSLTTEEEEEELLL
# prediction: LLLSSEEEEEEESSSHHHHHHHHHTTSLTTSLEEEEEELLLTTLLHHHHHHHHHHLSLEEEELLTTLELLTTEEEEELSTTLEEEEEETTEEEEEELSSLLLLSLLLHHHHHHHHHHHHHTTTEEEEEELSLSHHHHHHHHHHHHTTLEEEEEETTTLEETLLHHHHHHTTSLSEEEEGGGHHHHHHHHHHTTLLLLL
# prediction: LLLLLLHHHHLTTTSLLLEEEELLLLTSSLHHHHHHHHHHHLTTLHHGGGHHHHHHHHTLLLLTTLSHHHHHHHHHHHTLHHHHHHHHHHHHHHL
# prediction: LLLLLEELTTSLEELLLSLHHHHHHHHHHHHHHHHHTTLSEEEEESHHHHHHHHTLLLLLTSLLEEEEEETTSLEEEEELLLTTLHHHHHTTLSEEEELLLLTTLHHHHHHHHSGGLSEEEEEGGGSLHHHHHHHHHHSTTLEEEEHHHHHHHHL
# prediction: LLLLEEEEELLLLSSEEEEEEELLHHHHHHSLTTLLLLHHHHHHTTLLLLTTLEEEEEESSSLEEEEEEELLLGGGLL
# prediction: LLLLLLLLLLLTTLLLLSLEEEEEEELLTTSLEEEEEEESSSEEEEELTTSLEEEEEEELELELTTTLLEEEEEELTTLLSLEEEEEEETTSLELLLEEELL
# prediction: LHHHHHHHHHHHHHHHHHHTLLLLGGGTTLLLLLLTTLTTLTGLLLTTTLLLLELLTTLLLLLLHHHHHHHHHHHHHHHHHHHHHHHGGGLLGGGLLLHHHTTLHHHHHHHHHHHHHHHHHHLLLTTLLLEEELLLSTLLTTLLLGGGLLSLLLLLLLLHHHHHHHHHHHHHHHHHHGGGLHHHHHHHHHHHHHHHHHHHHLGGGHHGLLTTLLLLLLLLSSHHHHHHHHHHHHHHHHL
# prediction: LHHHHHHHHHHHHHHLTLLLLLLLHHHHHHHHHHHHHHHSSTTLLHHHHHHHHHHHHHHHHHHHHHHHHHTTLLLLTTLLLLHHHHHHHHHHHHHHHHHHHSLLHHHHHHHHHHHHHHHTLLTTSLEEEELLLSSLLLSTTLLGGGLTTLLSLLTTLELLLLLLLGGLLHLLTTLHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LGGGGSLHHHHHHHHHHHLTTLLLLTTLLLHHHHHHHHHHHGGGTLLSLHHHHHHHHHHHHHHHHHHLTTLLLLLTTSLLLLHHHHHHLLLLLTTTLLTTTLLLLLTTLLLLLLLLLLLLLLTTLHHHHHHHTLLGGGLHHHHHHLHHHHHHHHHHHHHHLSLSSLLHHHHHHTLLLLLHHHHHTTLLTTHHHHHHHHHHHHHHTTTLLHHHHHHHHHHHHHHHHHTLLLLTLLLGGGLLLLL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTTTLLLLSHHHHHHHHHHHHHLTTGLLLHHHHHHHHHHHHHSLHHHHHHHHHHHHHHHTHHHHHHHHHHHHHHHHHHHHHTLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LEEEEETEEEESSLLHHHHHHHHHHHHHHHHHHHTLLGGGEEEEEEEELTTTTLHLHHHHHHHHTTLSEEEEEEEEELLLTTLGGGEEEEEEEEELSSLGGGLLLTTLHHHHHHLLLLL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLTTLLLTTLTTLLHHHHHHHHHHHHHHHHHHHHHHHHTTLLLLLHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLLLEEEESSEEEEEEEEEEEELLSSLEEEEEEEEELLTTTLLLLLEEEEEEEESSTTEEEEEEEEETESTEEEEEELLLLTTTTLEEEEEEELTTEEEEEETTEEEEEEESLLLSSLEEEEEEEELLSSHHHHTTLLTTSSLEEEEEEEEEEEETTLEEELLLLLLLHHHHHHHLTTLHHHHHHHHHHHHTLLGGGLTLLLLLLLLL
# prediction: LLLLLLHHHHHHHHHHHSTTLLHHHHHHHHTLEELLLLLLLTTLLL
# prediction: LLLGGGTTLLHHHHHHHHHHHLTTLEEEEELTTLLLLTTLLTTEEEEEELTTTTEEEELLLLL
# prediction: LHHHHHHHHHHEEEEEEEETTSLEEEELTTLLLLLHHHHHHHHHHHHLGGGLLLTEEEETTEEEEEEEELTTEEEEEEETTTEEEEEEETTEEEEEEESSLLLHHHHHHHHHHHHHHHHHTTL
# prediction: LLTTSTTGLLLHHHHHHHHHHHHHHHHHHHHHHHTLTTLTTTLLTTLTTLLLTTLLLLHHHHHHHHHHHHHHHHHHLLLTTSLLLLGGGLLLLLSLLLLLLGGGGGGLGGLLLLHHHHHHHHHHHHHHHHHSTTLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLHHHHHHHHHHTLHHHHHHHHTLHHHHHHHHHHHHHHHHHHTLLTTSLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLLEEELHLHHHHHHHHHHHHHHHTLLHHHHHHHHHHSLHHHHTTLLHHHHHHHHHHHHHTTLEEEEL
# prediction: LLGGLLLLLTTLHHHHHHLLTTTTTLLLLLLLLLLLHHHHHHLTTLLSLLHHHHHHHHHHHLGGGHGGLLLLTTLLLLL
# prediction: LLLLSSLEEEEEEEELTTSLEEEEEEETTTTLEEEEEELTTLEEEELTTLEELTTLLLLL
# prediction: LLLLLLEEEETTEEEEEEEEETTLLLEEEEEEEETLEEEEEEEEEEETSSLLEEEEEETTEEEEEEELTSLLEEEEEEESSTEEEEEEEEEELTTSLEEELLEEEEEEL
# prediction: LLLLLLLLLLLTTTLLLLLLLLSLLLTLLLTTEELHHHHHHHHHHTTLEEEEETTTTEEEEEETTTLEEEEEL
# prediction: LLHHHHHHHHHSLHHHHHHHHHHHHSTTLTTEELHHHHHHHHHHHTLLHHHHHHHHHHHHHHHLLLLLGTSLEEEEEELTTSLEEEEEEEELTTLLLLLLHHHHHHHHHHHHHTTLSSEEEEEEELLLLHHHHHHHHHHHTTLLEEEELTTLLEEEHHHHLTTL
# prediction: LLGGGTTLGGGTTLLLLLTLLLLHHHHHHHHHHHHHHLLLTTTTLLEEEEEELTTSLEEEEEEEELTTSLTTHHHHHHHHHHHHHTTLLLTLEEEEEEEELTTSLLLHHHHHHHHHHHHTLTTLLEEEEL
# prediction: LLHHHLTLTTLLSLEEEEELLLTTLLLLLLTLHHHHHHHHHTTLLLEEELHHHHHHTTLLTTLEEEEELTTSLEEEEEEELTTLLTTEEEEELLLLLLTTLTTGTTLLLLTLLEEEEESSSLLLTTTTLLLLLEEEEEEEELLSLLLLLLTTSLLTTL
# prediction: LLEEEEEEEEEEEEEEELGGGTEEEEEEEEELTTSLEEEEEEESSLEEEEEEGGGTTEEELLTTLEEEEEEEESSLEEEEEEELTLLSTTGTTLLEEEEEESLHHHHHHHHHHHHHLTTLLLLHHHHHHHHSLLLELLEEEEELLLTTHHHHHHHHHL
# prediction: LEEEETTEEEEGGGLLLLTTGLLLGGLSEEEEEEEEETTEEEEHHHHHHHHHHHHHHTTLLLLLLHHHHHHHHHHHHHHHTLLSEEEEEEEELLLSLLLLLLLTTLLLLEEEEEEEELL
# prediction: LLHHHHHTTLEEEEELLLGGLLLLHHHHHHHHHHHHHHHHHHTTLSEEEEEETTEEEEEESSEEEEEETTEEEELLSSTTGLTTLLHHHHHHHHHHTTLLEEEEELLHHHHHTLSEEEEELTTSTEEEEEEETTEELLTSLLLHHHHHHHHHHHHHLL
# prediction: LLLTTHHHLLTLHHHHHHHHHHHHHHTLLLLLLLLLL
# prediction: LHHHHHHHHHHHHHHHHTLLTTLLGGGHTTLLLLTTSLLLLLHHHHHHHHHHHHHHHHHHLLLTTLEEELTTTLEEEEHHHHHHHHHHHHTLSSLHHHHHHHHHHTLSEEEELLLTTLL
# prediction: ...
# prediction: LLLLLLLHHHTTLLLLLHHHHTTLEHEELL
# prediction: LHHHHHHHHHHHHHHHHHGTTLSEEEEEHHHTTLLLLLHHHHHHHHHHHHHHHTLLGGGGEEEETTSLEELLLTTLEEEEEEELSSSSSLEEEEEEETTLEEEEEEEELL
# prediction: LLEEEEGGGSLGGGGGGHHHHHHHHHHHHHTTLLLLLEEEEEHHHHHHHHHTTLLLLHHHHHHHHHHHHHHHHHHTLLLLLTTSLEEEEELLLLTTLLHHHHHHHHHTTLLHHHHHHHHHHHLLHHHHHHHHHHHHHHHHHHHHTSLHHHHHHHHHHHHHHTTLLLLTTLLHHHHHHHHHHHHHHHHHHHHTLLLLSLHHHHHHHHHHHHHHHTTSHHHHHHHHHTTLLTGLLLEEEEELL
# prediction: LLLLLLTTLEEEEEEESLTTTLLSLLEHHHHHHHHHHHHHTTLLLSSLHHHHHHHLHHHHHHHHHHHHHHHHHHHHHEEEEEEEETTEEEEEELSSSSLLHHHHHHHHHHHHHTTSSLHHHHHHHHLLLL
# prediction: LLGGLLLLLLHHHHHTTLEEEEEELLLTTLEEEEEESSHHHHHHHHHTTLLEEEEESTLLGGGHHHHHHHHHHHEHTSHHHHHHHHHHHHTTLEEEEEESEEEEETTTTEEEETTEEELTTLEEEEETTTLLEEELLLLLLLLL
# prediction: 
# prediction: LLLEEEEEELTTSLEEEEEEELLTSSSSLEEEEELLTTTLLHHHHHHHHHHHHTTLEEEEEGGHLTLSTTLLLLTTLHHHHHHHHHHHHHSLHHHHHHHHHHHHHHHHHSTTLTSLEEEEEETHHHHHHHHHHHHTTLSEEEEELLLLHHHHGGGGGGLSSLEEEEELTTLTTSLHHHHHHHHHHHHHLTTEEEEEETTLLGGGGLTSSTTLLHHHHHHHHHHHHHHHGGGHL
# prediction: LEEEEELLLLTLHHLTTLLLLLLLLTTLLLLLLSLEEEELGTTTLLEEEEEEEELLHHHHHHLLLEEEEEETSLLLLLTTLLEEEEEEEELTTSLEEEEEEETTTLLEEEEEEEELSLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHGGGSLHHHHHHHHHHHHHHHHHHHTTLHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LHHHHHHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHSLTSLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLTTGTTLHHHHHHHHHHHHHHHHHHHHHHGGGGSTTLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTTSLHHHHHHHHHHHHHHHHHHHHHHHHSGGGLLL
# prediction: LLEEELLEELLLLLTTLLLLHHHHHHHHLLLLHHHHEEEEEEEEELLTTLLTTLEEEEEEEEEEEEEELTTLLLEEEEEEEELTTSSLEEEEEETTLEEEEEEEEEEEEELTTLLEETEEEEEEEEELTTSLLLEEEEELTTTLLEEEEEELGGGSLLLLLSSLLLTTLLEEEEEEEEEEETTTLEEEEEEEEEELL
# prediction: 
# prediction: LLLTTLLLLGGGGTLLLLSLHHHHHHHHTTLLLHHHHHHHHHHHHHHLHHHHHHHHHHHHHHHHHTTSLHHHHHHHHHHHLLLHLGGGHHHHHHHHHHHLLLLHHHHHHLLHHHHHHHHLTTSHHHHHHLGGGTTSLHHHHTLHHHHHHHTTLLTTLLSLLLLHHHHHHHHHHHHHHHHL
# prediction: LLLLLEEEEEELTTHHHHHHHHHHHHHHHHHTTSSLTTEEEEEEESSTLLHHHHHHHHHHHHHHHLSLHHHHHHHHHHLEEEELLTTSHHHHHHHHHHHHHHHHHHTLLLLEEEEEESLGGGHHHHHHHHHHTTLLLSTLLEEEEEELLTSSLHHHHHHHHHHHHHHSLGGGEEELL
# prediction: 
# prediction: LLHHHHHHHHHHHHHHHTTLHHHHHHHHHHHHHHHTLLLSHHHHHHHHHHTTLLHHHHHHHHHL
# prediction: LLEEEEEELSSTHHHHHHHHHHHHHHHHTTLEEEEELHGGGTLEELTTSLLLHHHHHHHHHHTSLLLGGGLLTEELSSLLLHHHHHHHHTLLLLHHHHHHHHHHHHHHLSEEEEELLSLTTLLSLTTSLHHHHHHHTTLLEEEEELTTTSHHHHHHHHHHHHHHTTLEEEEEEELLLLLTTHHHHHHHHHHHHHSSSLEEEEELLLLLGLGGGGLLGGLL
# prediction: LLLEEEEEEELTTTTTTSLLLSLLLTTLHHHHHHHHLSSLEEELTTLEEEEEEEEEEEESSTTEEEEEEELLHHHHHTTEEEEELEEEEEETTTSSEEEEEEELSSSLEEELTTLEEEEEEEEEEEEEEEEEELLL
# prediction: LLHHHHHHHHHHHHHHHTLHHHHHHHHHHHLGGGGGGSGGGTTLLGGGGTTSHHHHHHHHHHHHHHHHHHHTLTTHHHHHHHHHHHHGGGTLLHHHHHHHHHHHHHHHHHHSLSHHHHHHHHHHHHHHHHHHHHHL
# prediction: 
# prediction: LEEEEEEEEEEEEEEEEETTLEEEEEEEEGGGEEEEELTTLHHLTEEEELTTLEEELGGGTLLLLLEEEEEELLTTLLHHHHHEEEEEELSSHHHHHHHHHHHHHHTHLGGGL
# prediction: LLEEEEEELHHHHHHHHHHHLTTLEEEEELLLEELLLLTTTLLLLLLELLTTGTLLLEEEELTTHHHHHHHHHHHHHTLSEEEEESLTTHHHHHHHHHHHHHHTLLGGGLLEEEEEEELHHHHHHHHHSLLLLLGGGLL
# prediction: LLLLLHHHHHHHHHHHHHTLLHHHHHHHHHHHHHTTLLLEELLLLSLLLHHHHHHHHHHHHHHHHHGHSLSSLLHHHHHHLLLLLTTLLGGGGTTLLHHHHHHHHHHHHHHHHHHHL
# prediction: LLLGTTLLTTLBLSEEEELSLHHHHHHHHHHHLSLEEEEEEHTTEEEEEEEETTEEEEEEELSTHHHHHHHHHHHHHHHHTLSEEEEELLLLLLLTTLLTTLEEEEEEELLLLHHHHHHHTTLLLLLLLLHHHHHHHHHHHHHTTLLEEEEEEELLGGLLLTTHHHHHHHHHTTLEEEEELHHHHHHHHHHHTLEEEEEEEEEELTTTTLLLLHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: 
# prediction: LLLLLLLLLGGGTTLEEELTTSLEEEELLTTLEETTLLL
# prediction: LLLLEEEEEEEEEEGGGTLLLLTTTTTLLLEEEEEEEEEEEEEELLTTLEEELTTLLEEEEEEEEELEEEETTEEEEEEETTEEEEEEEEEEEEL
# prediction: LLLLLLLLHLLHHHHHHHLLL
# prediction: LLLTTLLGGGHHSSEEEEEEEESLSSTTGTTGGLEEEEEEEELTTTEEEEEEEEEETTEEEEEEEEEEELSSLEEEEEEEETTEEEEEEEELLHHHEEEEEEEEEETTEEEEEEEEEESSTTLLHHHHHHHHHHHHHTTLLGGGEEELLLLLLLHHHHHHHLLL
# prediction: 
# prediction: LHHHHHHHHHHHHHHHSLLGLLGGGSLHHHHHHHHHHHHHHHHHTTLHHHHHHHHHHHHHHHHHHHHHTTTLTTLLLTTSLHHHHHHHL
# prediction: LEEEEESSLLLHHHHHHHHHHTTLSEEEESSHHHHHHHHHHSTTSTTEEEEEEEEETTEEEEELLSSLLLTTLLLLLTTLLLLTTSLLLEEEEEEELLTTTTLELLEELTSLLEEEEELL
# prediction: LLLLSLEEEEEELLLLLLHHHHHHHHHHHHHHHHTTLEEEEEEEEEELTTLEEEEEELHHHHHHHHHHHHHHHHHLEEEEEEELLTSLLHHHHHHHHHHHHHTLLEEEEEELGGGGLLLHHHHHHHHHHHHHHHHHHTLTTTTSLEEEHHHHHHHHTLHHHHHHHHHHHHHHHHHLL
# prediction: LLLLLEELLLLLLLTTLEEEEEEEEELTTSLELLLLEEEEELLTTLEEEEEELLLLTTLLEEEEEEEEELTTLLLLEEEEEEEEEETTTTEEEEEEEELL
# prediction: 
# prediction: LLLLTSLLLLLLLEEEEEEEELLTTSLHHHHHHHHHHHHHHHHHHSSLEEEEELSSLLSEEEEEEEELLLLLLTTLLTTLLEEELLLLLTTLLLLEEELTTSLLLLTLSLLLHHHHHHHHHHHHTTGGGLSSTTLEELEEELLLSLLLLLHHHHHHHHHHHSLLSSLLLLLSLLL
# prediction: LLHHHHHHHHHHHTLTTLLHHHHHHHHHHHHHLHHHHHHHHHL
# prediction: LLEEEELLTTLLLTTLEEEEEEEEELEEEESSEEEEEEELTTSLEEEEEEEETTSLLLLLGGGTTEEEEEELLLSLEEEEEETTLLGGGEEEEEEEEETTTEEEEEETTEEEEEEELLSSLLEEEELLLLLTLLLTLEEEEEEEEEELLSSLEEEEEELSLLLSLLLLLLLEEETTEEEEEEEEEEELSLLTTLEEEEEEELTTTLLLEEEEELLLLL
# prediction: 
# prediction: LLEELLTTLLLTTTGTTSLGGGEETSEEEELGGGLLLLLTTGGTLLTTLLLLLL
# prediction: LLHHHHHHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHGGSLHHHHHHHHHHHHHHHHHTSLLLHHHHHHHLLLGGGGHHHHHHHHHHHHHLTTLHHHHHHHHHHSGGGGGGGGSLLLSGLLL
# prediction: LLLHHHHHHHHHHHHHHHHLLLTTHHHHLTTLLHHHHHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHTSLLLHHHHHHHHHHHHHHHHHHHHLLLLLGGGEEEELTTLLLHHHHHHHHHHHHHHHTLLLLLLL
# prediction: LLLEEELLSSEEEEELLTHHHHHHHHHHHHTLLLTTLSEEEELLLTTLSTTLHHHHHHHHHHHHHLTTGEEEEELSHHHHHHHHHHHHHHHHHHHHLHHHHHHHHHHHHHL
# prediction: LLEEEEELTTLSSSLLLTTLEEEEEEEEELTTSLEEELLSLTTSLEEEETTTTEEEEHHHHHHHTLLTTLEEEEEELHHHHHGTTTLTTLLLTTLEEEEEEEEEELL
# prediction: 
# prediction: LHHHHHHHHHHHHHHHHHHTTSLLLLLLEEEEEETTEEEEELTSLLGGGLLGGGEEEELTTSLEEESLLLLHHHHHHHHHHHHLTTLSEEEELSHHHHHHHHHHTSLLLLHHHHHHHHHTSLLLEEEELLTTSHHHHHHHHHHHTTLSEEEETTTEEEEEESSHHHHHHHHHHHHHHHHHHHHHHHLLSLLLLLLHHHHHHHHHHL
# prediction: LLLLLLTTSLLLLLGGGHHHHHHHHHHHHLLLLSSLLLHHHHHHHHHHHHHHHHHHHHTTSSLHHHHHHHHHHHHHHHTTLLGGGSLEEEEELSHHHHHHHHHHHHHHHHHHHHHTLLTTLSSLLLTTHHHHHTLL
# prediction: LLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTTLEEEELLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLHLLGTTLLHHHHHHHHHHHHHHHTSLLEELSSHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLTTTTLGLLLLLTTLLLTTLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTTLLL
# prediction: LHHHHHHHHHHHHHHHHHHLTSHLHHHHHHHHHHHHHTTLLHHHHHHHTTSSLHHHHHHHHLGGGL
# prediction: LLEEEEEELTTSLEEEELLTTLBHHHHHHHTTLLLLTHHHTTLLLEEEEEEEEEEEELTTGTLLLHHHHHTTLEEEEEEELSSSEEEEELLGGGLL
# prediction: LLELLLLHHHHHHHHHHHTLTTLLHHHHHHHHHHHHHLLLLLHHHHHTTLLLLGGGTLTTSLEEEELLLGSTTLLHHHHHHHHHHHHTTLLLLSLTTSSLLEEEEEELLLLLTTLL
# prediction: LLLLLEEEEELLTTSLLLLEEEEEELHHHHHGTGHHHHHHHHHHHHHHHHHHHHHTTLLLLHHHHHHHHHHHHHHHHHTTLLEEEEEELLTTLEEEEEEEELTTEEEEEEELLSLGGGGGGLLLGGGGGSHHHHHHHHHHHHHHHHHHTSGGGGGGSTTLLLLLTTLLLHHHHHHHHHHSLLLLLL
# prediction: LLLLLLLTTLLHHHHHHHHHHHHHHHHHHHTTLLLEELLHHHHHHHHHHHHHHHHHHHHHHHTTSLTTHHHHHHHHHSLLTTTLHHHHHHHHHHHHLLLLGGGHTTLLTLHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLHHHHHHHHHHHHHHHHHHHHHHHTLLLSLTTLLEEEEEELTTSLEEEEELLHHHHHHHHHLL
# prediction: 
# prediction: LLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLGGGGGGSLHHTTLLSLLHTLHHHHHHHHHHHHHHHHHHHHHHHHTLLLLHHHHHHHHHHHHHTTLLGGGHHHHHHHHHHHHHHHHGGGLLHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLLLLLLEEELLLLTTHHHHHHHHHHHHHHHHHHHSLLSSLLLGLLLLLLLEEEEEEELTTGLEEEEEEEEEEEEEEETTEEEEEEEEEELHHHHHTTLLLLLHHHHHHTLLLLGGGHHHHHHHHHHHHHHHSLGGGHHHHHHHHHHHHHLHHHHHHHHHHHHTLLLLLLLLLLLLLLL
# prediction: LLLHHHHTLLLLLLLTTHHHHHHHHHHHHHHHHHHHHHHHHHTTLLTSLEEEEEESLTTTTTHHHHHHHHHHSSSTTLEEEEEELLTTSLLHHHHHGGTLLHHHHHHHHHHHHHHHHHHLLTTLLHHHHHHHTTLLLLLLLHHHHHLL
# prediction: LLHHHHHLLSLEEEEEEEEEEETTEEEEEEEEEEEETTTEEEEEEEEEESSLLSSLHHHHHHHHHTTHHHHLLLLTTLLHHHHHHHHSTTTLEEEEEEEEETTEEEEEEEEEEEETTEEEEEEEEEEEELLTTSLTTLLLLELLLLLEEEEELTLTTTTEEEEEEEEEEELTTSEEEEEEEEEELSLLLSSLELLLTTEEEEEEEEEESLTTLLTTEEEEEEEEEEEELL
# prediction: 
# prediction: LLLLLTTLLLLGGGGHHHHHHHHHHHHHTTLLEGGLSSHHHHHHHHHHTTLLLTGGGGSLHHHHHHHHHTTLLLEEEEELLSLEEEEEEEEEEEEEEEEGGGSLSEEEEETTSLLL
# prediction: LHHHHHHHHHHHHHHTTLLLLLHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLLLSLLLLLHHHHHHHHHHHHHHHHHHHHHHTLTTLLHHHHHHHHHHHHHHTTLLHHHHHHHHHHHHHTSLLSLLHHHHHHHHTHHHHHHHHHHHHL
# prediction: LLLLLLLGGGSLHHHHHHHHHHHTTLLLLLTTTTLEELLGGGGSLLSTTLLEEEEEELLTTLSLLLLEEEEELTTTSLEEEESSHHHTLEEELLLL
# prediction: LLLLHHHHHHLSSLLHHHHHHHHHHHHHHHHLLTTLGGGGTTLLGGGLLHHHHHHHHTLLHHHHHHHHHHHHHHHLGGGGTSLHHHHHHHHHHHHHL
# prediction: LLLLLLLLLLGGTEEEEELLLLTTSHHHHHHTTLTTLEEEELLLTTSLSLLLEEEEEETTSLEEEEEEEEEELTTSLLLLEEEEEEEEEETTSSLLLSEEEEEELTTLSLEEEEEELLELEEEEEEEEEEEETTEEEEEEEEEEEELGGGHLL
# prediction: LLLLLLLLLTTLETTEEEEELLHHHHHHHHHTTLLEEEEEEESLLTLLLL
# prediction: 
# prediction: LLLEELSLLLSLLLTTLEEEEEESSSLLEEEEEELLLLLLLLLTTLEEEEEEEEEETTTEEEEELLSSTTLLLLLEEEEEEELTTSLEEEEEEEEEEL
# prediction: LLGGGEEEEETTTTLEEEGGGGTTLEEEEEELLLTLTTSSLHHHHHHHHHHHGGGTLEEEEELLLTTTTLLLLLHHHHHHHHHHLLTTTLLLLLLLGGGEEEELSTTLLHHHHHHHHHSLLLLLLHHHHHHLGGGLLLLTTLTTLEEEEEEEEEELTTSLEEEEEEESSLGGGGHHHHHHHHL
# prediction: LLHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: 
# prediction: LLLLLLTTEEEEEELTTSLEEEEEEELLLTTTTTLLEEEEEEEEEEETTEEEEEELLLHTTLLLLHHHHHHHHHHLHLLTTLHHHHHHHHHLLEEEEEEEEELTTLGGGGTLEEEEEELHHHHHHHHHHHHHLHHTTLLLLLTTLTTTLLEEEEEEEELTTLLLGGGLTLLLLLLLTTLLLHHHHHHHHHHLLLHHHHHLGGGLLSHHHHHHHHHHHL
# prediction: LLGGGTEEEEEELSHHHHHHHHHHHHHHTLEEEEEETTSLHHHHHHHLLSEEEEELLGGGTTSTTLSLLLHHHHHTTLLEEEEEHHHHHHHHHTTLEEEELSSLLEEEEEEEEESSSGGGTTLHHHHLTTSLLLEEEEELTTLEEEELLTTLEEEEELTTLSEEEEEETTTTEEEEEELTTLLLSHHHHHHHHHHHHHHHTLLLLL
# prediction: LHHHHHHHHHHHHHHHHLTSLEEEEELSSHHHHHHHHHHHHHHHTTEEEEEEELTHGGTTHHHHHHHHHHHHHLLEEEEEEHHHHHHHHHTTLLLHHHHHHHHHHHHHHHHHHHHHHLTTLEEEEELLLHHHHHHTTLEEHHHHHHHHHHHHHHHHHHTTLLGGGHTLLLLLLTTLLL
# prediction: LLLLLLHHHHHHHHHHHHHHHHSLHHHHHHHHHHHHHTTLGGGGHHHHHHHHHHHHHHHHHHHHHHHHHTLELL
# prediction: LGGGSLTTSEEEEEEEEEEEETTTLLEEEEEEELGGGEETTTTEEETTLHHHHHHTTLLTTLEEEEEEEEEEEEEEL
# prediction: LLGGGTTLEEEEELSSHHHHHHHHHHHHHHTLEEEEEEETTSEEELTTSLLHHHHHHHHHHHSLLTTLTTLEELLHHHHHTSLLSEEEELLLTTLBLGGGGGGLLLSEEEELLSSLLLHHHHHHHHHTTLEELL
# prediction: LLLEEEEEEEEEEELLLLLLLTTLLHHHHHHHHLTTLLTTLLLLEEEEEEEEEEEELTTTLEEELHHHHHHHHHHHHHGTTLGGGLLTTSGGGTTLLLHHHHHHHHHHHHHHGGSLTTEEEEEEEEELTTEEEEEELL
# prediction: 
# prediction: LLEEEEEEEEEESLHHHHHHHHHHHHLLEEEEELTTEEEEEELSSSEEEEEEELSSTTEEEEEEEESSHHHHHHHHHHHHHTTLEEEELLHHHHHHTTLLEEEEEELTTSLEEEEEELLLLLLLSLLLLLLL
# prediction: LLLLEELTTLLEEEEEEESLHHHHHHHHHHHHLLEEEEEEEEELLTTLEEEEEEEELSSSLLEEEEEELSSTTEEEEEEEEESSHHHHHHHHHHHHHTTLEEEEEELLTTTLEEEEEEELTTSLEEEEEELLLLLLTTLLLEELLLLLGTTLLLL
# prediction: LLLLLLLLEEEEEEETTEEEEEELTTLEELTTSLEEEELSLLTTSLELLLL
# prediction: LLLLLLLHHHHHHHHHHHHTTLLHHHHHHHHTLLHHHHHHHSLHHHHHHHLL
# prediction: LLLLLLLLTTLHHHHHTTLLLLGGGLLLLLLLLTTLLLTGLLLHHHHHHHHLHTTLLGGGLLLTTSTTLLLLTTSEEEEELLLLL
# prediction: LLLHHHHHHHHHHHLLTTHHHHHHHHHHHHHHHHHHHHHHLGGGGGSHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLHHHHHHHHHHHHHHL
# prediction: LEEEEELTTTSEEEEEEEEEETTEEEEEEEEEEELLTTLHHHHHHHHHHHHHHHHHHHLLSEEEEEHHHHTSLHHHHHHHHHHHHHHHHHHHHTTLLEEEELHHHHHHHHHLLSLLLHHHHHHHHHHHHTLLSLLLLLHHHHHHHHHHHHHHHHHHHL
# prediction: LLEEEELTTSTTLLGGGLLLLGGGGGGEEEEEELHHHHHHHHHHHHHHHHHHHTTLLEEEEEEETTHHHHHHHHHHHHHHHHTTTTLLLLEEEEEEEEEETTTSEEEEEELTTSLLTTLEEEEEELLSLSHHHHHHHHHHHHHHLLSEEEEEEEEELSSLLLTTLLLSEEEEEELSEEEEEEEELTTTTLTTLLEEEEELHHHHHHHHL
# prediction: LLLEEEEEETTSLEEELLTTLLLLTTLLEEEEEELTTEEEEEEEETTLEEELLLLEEEELTTSLEEEEEEEELTTSEEEEEEELTTSLEEEEEEEEEEEEL
# prediction: LLHHHHHHHTLLLLLEEEEEEELTTEEEEHHHHHHLLSSLEEEEEELTTLEEEEEELTTSEEEEEEEELLLTTTTLEEEEETTEEELLLHHHHHHHHL
# prediction: LLLLLEEEEEETTSEEEEEEEESSSLEEEEEETTEEELSTLLEEEEEELSSLLSLEEEEEEEELLSEEEEEEELLLLL
# prediction: 
# prediction: 
# prediction: LLEEEEEEEESSEEEEEEEEEEELTTSLEEEEEEEEEELLTTLEEEEEEEETLLLSLEEEEEEEEETTLLLLTSLEEEEEEEEEELTTSLEEEEELTTLLLTTEEEEELLL
# prediction: LLEEEEETTLLLLLLGGGGTTLEEEEEESSHHHHHHHHHHGGGTLEEEELSSHHHHHHHHHTTSLSEEEELHHHHHHHHHTSTTTLLLEEESLLLLLGGGLL
# prediction: LLLLLLHHHHHHHHHHHHHTTHHHHHHHHLLLLGGGGGLTTLL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHL
# prediction: 
# prediction: LLLLLLTTLLEEEEEELTTSLEEEEETTEEEEELTTSSSLELHHHHHHLTTSLSTLSEEEEETTEEEEEETTEEEEEELTTSLEEETTLLEEHHHHHLLLLLLLGGGLSEEEEETTTTEEEEEETTEEEEEETTTTLELLLTTLLLLGGGLLEEEEESLLLLTTGLEELSTEEEEEELTTEEEELHHHHHHHHTTLLLLLLHHHHHTLLL
# prediction: LLLLHHHHHHHHHTTLLLLLSLLLHHHHHHHHHHHHHHHHHHHHHTTLLLLLHHHHHHHHHHLLLLLTTLLLLLL
# prediction: LLHHHHHHHHHHHHHHHHHHHHHLLTTTLLLLLLLTTTLLLLLHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHTHHHHHHHHHHLLLLLLLL
# prediction: LLLLEEEEEEEESSLLLGGGEEEEEEEELLTTLLSEEEEEELTTSLEEEELTTSHHHHHHHHHHHHHHHHL
# prediction: LLLLLLTTLHHHHHHHHHHHHHHHHHHHHHHLHHHHHHHLHHHHHHHHHHHHHHHHHHHHHHHHHHHHGGHHLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHSLLL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTTLLLLLLLHLHHHHHHHHHHHHHHHHHHHHLTTGGGGEEEELLHHHHHHHHHHHHHHHLLLHHHHHHHHHHHHHTLHHHHHHHHHHHLGGGHTTLTTLLLHHLLLLGGGEEEEELLHHHHHHHHHTLLLLLTTTLLLLTHHHHHHHHHHHHHTTTLLEEEEEESLLLLLLLTTTLLLLEEEEEEEELTTLLLLLLLLLLELLLLLLLLL
# prediction: LLLLLLLLTTLSLEEEEEESSLLHHHHHHHHHHHLLEEEEELHHHHHHHHHHTTSLSEEEELSTTLLHHHHHHHHHHHHHTTLEEEETTHHHHHLTTTTLLLLEEEEELLLTTLTTHHHHHLTTEEEEESLHHHHHHHHHHHHHHHHHHHHLL
# prediction: LLLLLLLEEEEEGGGEEEEEEEESSTTSEEEEEEEEETTTTLLEEEEEEEEELTTLLHHHHHHHHHHHHHHHHLLLTTEEEEEEEEESSSLEEEEEEEL
# prediction: LLLLHHHHHHHHLLLLLLLTTSLLLLHHHHHHHHHHHHHHHHHHHHTTLEEELHHHHHHHHHTTLEEEEEELLLLHLHHTSLLLLTTTSLLLLLLLLLHHHHHTTLLLHHHHHHHHHHHHHHHHHHHTSLLTTLLHHHHHHHHHHTTLLLLLTTLLHHHHHHHHHHHHHLGGGLLLHHHHHHHHHGGSLTTLLLLEEELLGGLL
# prediction: LLLLLLLLLLTTTTGGGSLHHHHHHHHHHHHHHHHHHHHHHHTTLTTTTSLHHHHHHHLSSLHHHHHHHHHHHHHHHHHHSLL
# prediction: LLHHHHHHHHTLLLLLLTTLLLTTGGGGSTTSLTTLTTLLLELLLSSLLLTTLLEHHHELLL
# prediction: LLSLLLHHHHHHHHHHHSLHHHHHHHHHHHHHHHHLLEEEEEEELTTSLEEEEELSTTTSTTTTTTEEEEEEELHHHHHHHHHHHHLHHHHHHHHHHHLHHHHHHHHHL
# prediction: LLEEEEEELTTTTSLHHHHHHHHHHHSTTLHHHHHHHHHHHHHHHHHHHHHHTLLLLHHHHHHHHHHHHHHHTTLLLLHHHHHHHHHHHHHSLTLTTHHHHHHHHHHTTLEEEEELSSLHHHHHHHHHHTTLGGGLSEEEEESLLLLLLLLHHHHHHHHHHHTLLGGGEEEEESSHHHHHHHHHTTLLEEEEELTTLLLLLTTLLLSEEESSHHHHHHHL
# prediction: 
# prediction: LLLLLLLLLLLLLLTEEEESSTTLEEEEEEEEETTEEEEEEEEEEEEEEEEELLSTLLEEEEEEEELTTSLELLLLLLLGGGTTLLTTLLLLSLLLLLGGGGLLLGGGSLLLLSSLLLLEEEEEEEEELLTTSLEEEEEEELLLLLTSLSLLLEEEEEEEEEETTLEETTEEELLLEEEEEEEELL
# prediction: LLLLLLLLLLLLLTTLLHHHHHHHHHHTLTTLLLLTTLEEEEEESTTSEEEEEEELLTTLLLHHHHHHHHHHHHHTTLTTTLLLLLSTTLLGGGTEEEEEEEELL
# prediction: LLLLHHHHHHHHHHHHHHHHHHHHHTTLLTTSHHHHHHHHHHHHHHHHTTLLHHHHHHHHHHHSLGGGHLTTHHHHGGGEEEEEELTTSLEEEEEELLLL
# prediction: LLTLLEEEEEEEELSSSLEEEEEELLHHHHLGGLLLLHHHHTTLEEEELTTLEEEELTTLEEEEEEEEETTTEEEELLTTLLLSLL
# prediction: LHHHHHHHHLTTLEEEEELTTLHHHHHHHHHHHHSLLLTTLEEEEEELLSSLHHHHHHHHHHHHLLLLSLEEEETTEEELLHHHHHHHHHTTHHHHHHHHTTLLL
# prediction: LLLLLLLLLLTTLEEEEEELSSSHHHHHHHHHHHHHTTEEEELLLHHHHHHHHHHHTTLLHHHHHHHHHHTTLLLLTTLLHHHHHHHHLTTGSLHHHHHHHHTLLLLHHHHHHHHHHHHHHHHHHHHHHTLHHHHHHHHHHHHHHHHHHHHHL
# prediction: LEEEEELGTGLHHHHHHHHHHHHHHHHHLSEEEEEELSLLLEEEEEELLTTSLLLLLLTTSLEEEEEEHHHLTTLLHHHHHHHHHHHHTTLLLLLLSLHHHHHTTLLLLLLLLSSSLLHHHHHHHHHHHHHL
# prediction: LLHHHHHHHHHTLLLEEEELTTSLEEEEEEEELLSLHHHHHHHHHHHHHTTLLTTSLLLHHHHHHHHHHHHHHHHHHHHHHLLLLLGGGGSLHHHHHHHHHHHHHHHHHHHHTHHHHHHHHHTTLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLHGGGHTL
# prediction: ...
# prediction: LLLLTTTLLLLLLLLLLHHHHHHHHHHHHHHHHTTLLEEETTTTEEEELHHHGGGLHHHHHHHHHHTTLLGGLL
# prediction: LLLLLLLSEEEEELLSLLTTLLLLHHHHHHHHHHTTLLLLLEEEEELTTSLEEELLLTTLLLTTLTTLLTTEEEEEEELLLLTTSLLGGGLLHHHHHHHHHHHHHHHHHLTTLEEEEGGGLLTTTLHHHHHHHHHHTTLLLLTTLL
# prediction: LLLLLLLSLLLTTLLHHHHHHHHHHHHTSTTTTLLLLLLSTLLHHHHHHHHHHHHHTTLLLSEEELHHHHHHHHHHHHTLLL
# prediction: LLLLLHHHHHHHTLLTTTTLLLHHHHHHHHHHHHHHHHHHHHHHTTSLEEEEEEELLHHHHHHTTLLTTLTTEEEEEEEEELSSSLHHHHHHHHHHTTLLEEELLLLTTTLLEEEEELLTSLLLLLTTLLL
# prediction: LLGGGTLTSLLLHHHHHHHHHHHHHHHHHHHTLGGGTTLEEEEELLSHHHHHHHHHHHHTTLEEEEELSLHHHHHHHHHHTTLEEELHHHHHTSLLSEEEELGTTTLLLGGGGGGLLLSEEEELLLLLLTSHHHHHHHHHTTLEEEESEEEEHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLL
# prediction: LLLTEEEEEEEELTTHHHHHHHTTLLHHHHHHHHHLLLEEEEEEETTEEEEEEEETTSLEEEEEETTLEEEEELTTSLEEEEEEEEETTEEEEEEEETTEEEEEEEEEETTEEEEEEEETTEEEEEEEEEL
# prediction: LLLLLHHLLHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHTTLHHHHHHHHHHHHTSLGGGSLLLLL
# prediction: LLHHHHHLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLLTHHHHHLLTTGGGLLLLLTTSLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLTTGHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLLLLLLLLLLLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLLHHHHHHHHHHHHHHHHHHHHHTLLHHHHHHHHTLLHHHHHHHHTTSSLLLHHHHHHHHHHHTLLGGGHLHHHHHHHHHHHHHHL
# prediction: LLEELLTTTHHHHHHHHHHHTLLGLLLTHHHHHHHHHHHHTLLLLLLLTTLLEELLLLLTTLEEEELTTLEEEEEEEEEEEEELL
# prediction: LLLTLHHHHHHHTTLEEEEEETTSLLEEEEEEELTTSLEEEELLLLLLLLLGGGLLLGGGHHHHHTTLLLHHHHHHHGGSLGGGEEEEEESSTTEEEEEEESSHHHHHHHHHHHHHHHL
# prediction: 
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHSHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTL
# prediction: LLLLHHHHHLLSLHHHHHHHHHHHTLLL
# prediction: 
# prediction: LLLLTTGLHHHHHHETTTEEEELLLSLLTLLLTTLEELSSEEEEEEELTTLTTEEEEEEEETTTLLLTTLLLTTSLTTLLLLELTTTTEEEEEEELTTSLEEEEEEEEEELL
# prediction: LLHHHHHHHHHHHHHHHHHHHTLSTTHHHHHHHHLLLLLTLLLLLLLTGGTTEELLSSLLLLTTLELLLSLTTTTLTTLEEEEELTTHHHHEEEEHHHHHHHHHHHTLLLLHHHHHHHTLHHHHHHHLTTLLEEEEEELLLTTLLLLHHLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLHHHHHHHHHHHHHHHHHHHHHHLLLLLLLLSLHHHHHHHHHHHHHHHHHHHHHHHLTHHHHHHHHHSLLHHHHHHHHHHHHHHHHHHHHSTTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLLLLTTLLLLLEEEEEEEEEEEEEEEEEEEEEEELTTTLEEEEEESSSLLLEEEEEEELLTTEEELTSLEEEEEETTEEEEEEEEEETTTEEEELLSSLEEEETSSLEEEEEEEEELTTLEELTTEELSTEEEEEEEEEEEEEEEETTEEEEEEEELL
# prediction: LLLEEEEEEEEETTTTEEEEEETTSLSEEEEEEEEELTTSLLLTTTTLEEEEEEEELSSLGGGGGEEEL
# prediction: LLLEEEEEETLLHHHHHHHHHHHHTTLEEEEEETTSTTEEEEESLHHHHHHHHHHHHHTTLSEEEELLLL
# prediction: LLLLLLHHHHHHHHHHHHLLSHHHHHHHHHHHHHHHLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLLHHHHHHHHHHSSLHHHHHHHHHHHHHHHSSHHHHHHHHHHHHHHHLLLLLLHHHHHHHHHHHHHHHHHHHHLTTTTSLHHHHHHHTTLLLLL
# prediction: LHHHHHHTLLLSLEEEEEELLLSSHHHHHHHHHHHHHTTLSEEEEELLSSLHHHHHHHHHHHHHHHLTTLEEEEELTTLLLHHHHHHHHHHHHHTTLEEEEELLLTTLHHHHHHHHHHLSSLEEELTTTSSHHHHHHHHHTTSLSEEEELHHHHTLHHHHHHHHHHHHHTTLLEEELLHHHHHHHHHHHSTTLSEEEEELLGGGGLLSLLEEETTEEELLSSLLLLLL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTTLELTTTTLEEEEELL
# prediction: 
# prediction: LLLLLLLLHHHHHHHTTLLLTTLTTLLLLLL
# prediction: LLLLEEELLTSEEEELLLLSSLEEEEEEEELTTSSEEEEEEEESSTTEEEELTTTEEELTTLEEEEEEEELLLLTLLGLGGGLLEEEEEEELLTTHHHHHHHHHHTTLLLLEEEEELEEELL
# ...
# prediction: LLLLLLLHHHHHHHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLBLTTSLBLLLHHLLTTSLTLHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHHHHHHHHHHHHSLSLLLLLLLSLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHLTTLHHHHGLHHHHHHHHHHHHHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHL
# prediction: 
# prediction: LLEEELLLHHHHHHHHTSLHHHHHTLSEEEEEELTTSLEEEEEHHHHHHHTLLHHHHTTSLHHHHHGGGTTSHHHHHHHHHHHHTTLLLEEEEEEEELLLLLEEEEEEEEEETTSTEEEEEEEEL
# prediction: LEEEEEHHHHHHHHHHHHTTTTTSLLSLEEEEEEEEEETTEEEEEEEETEEEEEEEEEELLTTSTEEEEEEHHHHHHHHHHSLTTLEEEEEEETTEEEEEETTEEEEEELSLGGGSLLLGGLL
# prediction: LLLLLLLLLLLLEELHHHHHHHHHHTTTLLLTTEEEEEELLTTLHHHHHHHHHHHHHHHTTLEEEEEEHHHHGLHHHHHHHTLLGGGEEEELLTSHHHHHHHHHHHHHTTLLSEEEEELGGGTSLHHHHHHHHHHHHHHHHHHHHHHHHHHTEEEEEEELSSHHHHHHHHHHHHHHHHHHHHHTTSLLLTLEEEEEEEELLLLLTLLEEEEEEEELLLLL
# prediction: LHHHHHHHHHHTTSEEEEEEEEEETTEEEELHHHHHHHHHHHLHHHHHHHHHHHHHHHL
# prediction: LLEEEEEEEETTTLLHHHHHHHHHHTTLLGGGEEEELLHHHHHHHHHLLTTLEEEEEELLTTTSLHHHHHHHHHHHHHTTLEEEEELLLLLTTSHHHHHHHHHHHHHHHHHHHHL
# prediction: LLEEELGTTSLEEEEEEEELSLSLEEETTEEEEEEEELSLSEEEELGGGLLTTSLLEELTTLLLEEEEEEEEEEEEEEESTTSSLEEELLEELLLLEEEHHHHHHHHTTLEEELL
# prediction: LHHHHHHHHHHHHHHLTTTTSLELHHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHHHHHHHHTTSLLLHHHHHHHHHHHHHLHHHHHHHHTHHHHHHHHHLTTSSSLBLHHHHHHHHHHTTLLGGGHHHHHHHHLTTSSSLLLHHHHHHHHHHHHHLLTTLLGGGLLLLLL
# prediction: 
# prediction: LLHHHHHTLSLEEEEEEETTTEEEEEETTEEEEEEEEEEELLLLLLTTTLLLTTHHHHHHHHHHHHHTLLEEEEEELTTLLLLTTSLEEEEEEETTEEHHHHHHHTTSEEEEEEELTTLLHHHHHHHHHHHHHHTTLLLLL
# prediction: LLEEEEEEESSSLEEEEEEEEEETTEEEEEEEEESLLTTLEEEEEEEESLLSTTLEEELLLELTTSLLLLLTTLTTLLTTLLEEEEELTTSLEEEEEELTTLLLLSTTLETTEEEEEESSLLTTTLTTLTTGHHHSLLLSLEEEEEEEEEL
# prediction: LLLLLLLLTTLLLLLLLLHHHHHLHHHHHHHHHHHHHHHHHHLHHHHHHHHHL
# prediction: LLLEELLLTTLLEEEEELTTSLBLLLTTLSSLLLLLLLGGGLTTGLLLLLEEELTTSLTTSLEEEEELTTLLEEEELLLLLL
# prediction: LHHHHHHHHHHHHHHHHHHHHHLLLLLLLLLLEEETTTTEEELLLHHHHLLLEEEEEEEEEEEEEEEEEETSEEEEEEEEELTTTTLLHHHHHHHHHHHHHHTLLHHHHHHHHHHHHHHHHHHHHHHLLEEEEEEEELTTEEEEETTHHHHHHHTSTTEEEEEEEETTEEEEELEEEEEEEELL
# prediction: LLLLGGLLTLLGGLLEEEEEEEEHHHHHLLLEEELLTTLLLLLLLLLLLLLLLTTSHHHHHHHHHHHHLGGGLLLLLLLLSLLLLEEEEEEETTEEEEEELTTLEEEELLLL
# prediction: LLGGGGSLLLLLTTGGEEEEEEEETTTTEEEEEEELLLTGGTGTLSSHHHHHHHHTLL
# prediction: LLTSLLLLLLLLLTTLLTTSTTLLLHHHHHTTSLLLTSEEEEELTTSSLLHHHHHHHHHHTTLEEEEEELHHHHHHHHHHHTLHHHHHHHHHTTLEEEEEEEEEEEETTEEEEEEEETTSEEEEEELTTLLTTGTTLLLLEEELSEEEEEEL
# prediction: LLLLLLGGGHHHHHHHHSLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLLLLLLHHHHLLTTLLHHHHLHHHHHHHHHHHHHHHLLTLLHHHLLLLSSLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTHLLLLHHHHHHHHLLLLLL
# prediction: 
# prediction: LLLLHHHHHHHHHHHHHHHLGGGGLHHHHHHHHTLLHHHHHHHLSSHHHHHHHHHHHHHHHHLLLLLLLTTSLHHHHHHHHHHHHHHHHHHLTTHHHHHHTSLLLHHHHHHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTSLHHHHHHHHHHHHTLHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLLHHHHHHHHHHHHTLHHHHHHHHGGLLLLHHHHHHHHHHHHHHHTSLHHHHHHHHHHHHHHHHSTTLL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHLLLHGHHHHHHHHHSLHHHHHHHHHHHHHHHHHHTTSSLHHHHHHHHLLLHHHHHHHHHHHHHSLHHHHHHHHHHHHHHL
# prediction: LLEEEEEEEEELSSSEEEEEEEETTTEEEEEEEEEEELHHHHHHLLHHHHHHHHHHHHHHHHHHHLTTLLSEEEEEEEEEEEEEEEEEEEEEEEEELSTLLHHHHHHHHHHHHHHHHLTTLHHHHHHLL
# prediction: LLLLLSLLLSEEEEEEEEEEEEEETTLSSEEEEEEEEETTTTEEEEEELTTLEEEELLLLLLLTHHHHHHHHHL
# prediction: 
# prediction: 
# prediction: LLEEEEHHHHHHHLSTTLEEEEETTEEEEHHHHHHHSTTHHHHHHHHHTSLTTHHHHHTTLLHHHHHHHHHTEEEELLGGGGGGL
# prediction: LEEEEEETTLLEEEEEEEESSSLEEEEEEETTEEEEEEETTEEEEELLLLLLLLLELELLGGGTSLSLEEEESLLGGGLEEEEEEEEETTEEEEEEEEEEEELLLLLLLTTLLEEEEEELLTTSLLEEEEELTTSLEEETTEEEEEESLLGGGLEEEEEEEEETTEEEEEEEEEEEEL
# prediction: LLEEELLTTTSLHHHHHHHHHHLLLLEEEEEEEELHHHHHHHHHHTTLLHHHHHHHHHHHHHHHLGGGGEEEETTEEEEEEEELEEEEEEETTTLEEEEEELTTLSLHHHHHHHHHHHHHHHHHTLLLLLLTLLGGGEEEEELLLLLLEEEEEELLTTTTTLLLLEEEEEEEEEETTEEEEEEEEEEETTTLLHHHHHHHHHHHHHHHHHHLL
# prediction: LHHHHHHHHHHHHHHLTTSSSLLLHHHHHHHHHHTTLLLLHHHHHHHHHHBLTTSLSLELHHHHHHHHHHHHHLSLLHHHHHHHHHHHLTTSLSLLLHHHHHHHHHHTTLLLLHHHHHHHHHHHLTTTTSLBLHHHHHHHHHL
# prediction: 
# prediction: LLLLLEEEEELLHHHHHHHHHHHHHHTTLSEEEELSSHHHHHHHHHHTLLSEEEELLLLTTLLHHHHHHHHHHSGGGTTSLEEEEESSSLHHHHHHHHHTTLSEEEELLLLHHHHHHHHHHHHHHHTL
# prediction: LLTLLEEEEEELLLTLTTSLLLLLLLEEEEELTTLTTSLEEEEELLLLTTHHHHEEEEEEEEELTTTLEEEELTTTLLELLLLLGGGLHHHHHHHHHHHHHHHHHTTLEEELLHHHHHHTLLLEEELTTTLLGGTTEBLTTSLBTTSTTEEEEELLLLLLTTTLLHHHHHHHHHHHHHHHHHHHHL
# prediction: LLEEEEEEELLLTTLLLLTTTLLLEEEEEELHHHHHHHLTTGGGGEEEEEEEEEEELLTTLLHHHHHHHHHHHHHHGGGLSEEEEELSSSHHHHHHHHHHHHHLLSSLEEEEELLLLTTSLLTTHHHHHHHHHHHHHLGGGTTLEEEEEETTEEEEEEEEEEELTTSHHHHHSTTLLLEEEEETTEEEEEELLLLLLLLLLLLLGGGGLLLL
# prediction: LEEEEEELTTLLHHHHHHHHHTTLSEEEEELLSTTLLLHHHHHHHHHHHHTTLEEEEELLLTTSLLLTTLLLLGGGGTLEELSSSLHHHHHHHHHHHHHTLSLHHHHHHHHHHL
# prediction: LLLSLLLHHHHHHHHHTLEEEEELTTLEEELTTLLLSEEEEEEEEEEEEEEELTTSLEEEEEEELTTLEEEEGGGLLTTLLEEEEEEESSLEEEEEEEHHHHHHHHHHLHHHHHHHHHHHHHHHHHHHHHHHHHHTSLHHHHHHHHHHHHHHSTTLLLLTTEEEELLLHHHHHHHHTLLHHHHHHHHHHHHHTTSEEEETTEEEEELL
# prediction: 
# prediction: LHHHHHHHHHHTTLHHHHHHHHHHHHHTTTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTLHLHHHHHHHHHHHHHHHHHHHHHHHHTLLLEEEELLLLHHHHHHHHTTLLLHHHHHHHHHHHHHHHHL
# prediction: LLHHHHHHHHHHHHHHHTLTTGLLHHHHHHHHHHHLGGGHLLHHHHHHHHHHHHTTTTSLBLHHHHHHHHHHHHL
# prediction: LHHHHHHHHHHHHHHHHHHHHHHHLLLLTTLLLLLLLLLLLLSSHHHHHHHHHHHHHHHHHHHHHHHHHHHTLLLLHHHHHHHHHHHHHHHHTLLLTTLLLLHHHHHHHHHHHHHHHHHHHL
# prediction: LLLLLLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHSLSLHHHHHHHHHTTLLLLLLLGGGTLTTLLHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHLLHHHHHHHHHHHHHSLLL
# prediction: LHHHHHHHHHHHTTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHHHHHHHHHHHHHLLTTHHTTSHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHL
# prediction: LLEEEELTTLLLLGGGLEEEEEEETTEEEEETEEEEEELSTTLSEEEEEEEELSLTTSLLLLLEEEEEEETTSTTEEELLGGGLLLLLLLLEEEEEEEEEEELGGGLLLLL
# prediction: LHHHHHHLTTSLEEEEELLHHHHHHHHHHHHHGGGLSEEEEELHHHHHHHHHHTTLLLLSLGLLGGGHHHHHHHHHHHHHTTLEEEELLSEEEEGGLLTTLLEEEEEGGGTLLTTLEEEELLHHHHHHHHHHHHHLSEEEEELLTTGGGHHHHHHHHHHHHHHHHHHHHTTLEEEELSHHHHHHHHHTTLGGGEEEEELLHHHHHHHHHL
# prediction: LEEEEEELSLLHHHHHTLLLLLLLTTLLHHHHHHHHHHHHHHHHTTLLLSEEEELHHHHHHHHHHHHHHHTTLLSSLEEEELLLLGGGTGTGTTSLHHHHHHHHHHHHHHHHHHTTTSLLLLLLTTSTTLTTTLGGGTTSLGGGSLSSSLHHHHHHHHGGGHHHHHHHHTTLEEEEEELHHHHHHHHHHHTTLLHHHHHTLLLLTTLEEEEEELTTSLBLSTTLLLLTTL
# prediction: LLEEEELLLLLTTLLLLLLLLLLLLLTTGLLLLHHHHHHHHHHHHSLGGGGTTLEEEEELLGGGGLHHHHHHHHHHHHHTTLLEEEELTTSLLLHHHHHHHHHHHTLSEEEEEELLLLTTSTTTLLEEEEETTTTLLLLHHHHHHHHHHHHHLLEEEELSLLLLLGGGLEEEEELLTTTLLLEEEEEL
# prediction: LHHHHHHHHHHHHSLHHHHHHHHHSTTLLEEEEELLTTTTHHHHHHHHHHHHLLLGGGEEEEEELTTSTTLLLLLLHHHHHHHHHHHHHTLLSEEEEELSSSSEEEEELTTLLL
# prediction: LLLEEEEELTTTSLHHHHHHHHHHHHHHHHLGGGTTLEEEETTEEEEEEEESEEEEELTTTLLEEEEEEEEEEETTSLEEEEEELLSSLHHHHHHHHHHHHHLLGGGTTSLHHHHHHHHHHHHHHHHHHHHHHLLSSLLLLL
# prediction: LLHHHHHHHHHHHHHTSHHHHHTTLLEEEEEHLHHHHHHHHHHHHTLLEEELLLLHHHHHHHHHTTLEEEEEEGGLLLLLTLLHHHHHHHHHHHHHHHHHHHTSLHHHHHHHHHHHL
# prediction: LLEEEETTEEELHHHHHHHHHHHHHHHHTTLLLLSSLLLLLLLLTTTLLLLLLSLEEEEEELLTSLLLLSSLLLLEEEEELTTSLEEEEEEELLLTTSLLEELL
# prediction: LLLLLEEEEELLTTSLHHHHHHHHHHHHHSLLLTTLSEEEELLGGGHHHHHHHHLSTTEEEEEEELLLTTLLTLLLLLHHHHHHTTLSEEEEELHHHHHHHTLLHHHHHHHHHHHHHTTLEEEEEELSLHHHHHTTHHHHHHHHHHHHHHHTSLGGGGGGEEEEELLLLLTTTSSLLLHHHHHHHHHHHHHHHHHHHLHHHHHHLEEEELLLLLHHHHHHHHTSLLEEEEEELGGGGLHHHHHHHHHHL
# prediction: LLHHHHHHHHLLLTTLSLGGGHTTTLLTLLTTLLSLLLSLLLLLLTTLSLHHHHHHHTTLLLLEEEEEEEEETTEEEELLTTSHHHHHHHHHHHHHHHHHHTSTTLGGGTTLLGGLL
# prediction: LLLLTTTTSLLLSHHHHHHHHHHHHHHHHHHHHLLLL
# prediction: LHHHHHHHHHHHHHHHHTTLLLTLHHHHHHHHHHHHHHHHHHHHHTHHHHHHHHHTTLLHHHHHHHHHHTTLL
# prediction: ...
# prediction: 
# prediction: 
# prediction: LLLLLLLTTTTLEELLLTTLLLLLLTTLLLLLLLLLTTLLLSHHHHHTSLLEELLLLLLLTTLLLEEEEELLTTLTTLEEEEEELLLLLTTLLLLHHHHHHHHHHHLLEEEEEEEEEELLTTLEEEEEEEELLTTLSSLLSHHHHHHSLEEEEEETTTEEEEEEEEEELSSLLLLLLTTTLLLLEEEEEEEEEESLLLTTLLSLEEEEEEEEELTTEEEEEEELLTLEEEEELLLL
# prediction: LLHHHHHHLLLTTLLLLLLLGGGLHHHHHHHHHHHLLLLL
# prediction: LLEEEETTTLLEELTTTTLGGGTLLTTLLGGGSLTTLBLTTTLLLGGGLEELLL
# prediction: LLHHHHHTLLHHHHHHHHHHHHHHHTLHHHHHHHHHHHHHHHLGGGGGGGGGGTTGGGGGTLHHHHHHHHHHHHHHHHHHHHTTLHHHHHHHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHHHTTLLHHHHHHHHHHHHHHHHHL
# prediction: LLLTTLLTTLEEEEEELTTSLEEEELLLLTTSLTLLLTTLLTTLLEELLLL
# prediction: 
# prediction: 
# prediction: LLHHHHHHHHHHHHHHHHHLLTTLTLLLLLLHTTHTTLLTTLSTTLLLLHHHHHTTLLLLHHHHHHHHHLGGGGSTTLEEELTTLSSHHHHHHHHHHHHHHHL
# prediction: 
# prediction: 
# prediction: LLLLHHHHHHHHHHTTLLTGTTLLGGGEEEEEEEEELSLTTLEEELTTSLEEEEEEEELLHHHHLTTLLTTLBLTTSSBLHHHHLSLHHHHHHHHHHHHHHTTLHHHHHHHHHHHTTSLHHHHHTTLLL
# prediction: LLLLEEEEEEEELSSTTTLLLLEEEEEEELLLTTLLLLLHHHHHHHHHHTTLLGGGLLLLTTLLLLLLLLLEEEEEEEEETTEEEEEEEEESSHHHHHHHTLGGGLL
# prediction: 
# prediction: ...
# prediction: ...
# prediction: LEEEEEEEETTTEELELLLHHHHHHHHHHHTTSLEEEELLHHHHHTSLLTTLLEEEEESLTTLLTTEEEESSHHHHHHHHTTLSEEEEELHHHHHHHHGGGLSEEEEEEEESLELLLEELLLLLGGGLEEEEEEELLTLTTLLLLEEEEEEEEL
# prediction: LLEEELLTTLLEEEEEELSLTTTTTLLEEELTTSLLLEEEELLLLLLLL
# prediction: LHHHHHHHHHHHTTLLHHHHHHHL
# prediction: LHHHHHHHHHHHHHHHHHHHHHTLL
# prediction: 
# prediction: ...
# prediction: ...
# prediction: LLLHHHHHHHHHHLLTLLLTLLHHHHHHHHHHHHHHTTLLLLLLEEETSLHHHHHHHHHSTTLELTTTLELEEELSSLEEGGGEEELLLLLLLLLLLLLLHTTLEEEEEETTSLEEEEEEEELL
# prediction: LLLEEEEEELLSSHHHHHHHHHHHHTLLEEEELTTGGGLEEEEEEETTEEEEEEEELTTSHHHHHHHHHHHHHHLSEEEEEEEESLHHHHHHHHHHHHHHHHHHTLSLSLEEEELLLLLGTTLEELHHHHHHHHHHHTLLEEEEETTTTLLHHHHHHHHHHHHHHL
# prediction: 
# prediction: 
# prediction: LLLLEEEESSLEEEEEEETTTLLEEEEEEELLTTLL
# prediction: LLLLLLLHHHHHHHHHHHHLTTLLLLLLLL
# prediction: LLLGLLGGGTTLELLLLLLSSLHHHHHHHHHHHHHHHHHHHHLLLLLLLGGGEEELLTTLLLTTTLLHHHHHHHHHHTTLLLGGGSLEEEEETEELLLLSSTLEEEEESLEELLTTLHHHHHHHHHHSLEEEEEELTSGGGLLLSSLEELSTTSSSLLEEEEEEEESSSEEEEEELLLTTTTTTTEEEEETTTTLTTLLLEEELLLLLLLLL
# prediction: LLLLTTLTTLLLTTTLBBLTTSLLLLLTTTTTTTLLTTLLLLLLLLLTLTTLLLLTTSLBLLTTSLLLLLLLLLLTTLLLLLLLLLLLLLTTTTLLLLTTTLLLLTTLLLLLLGGGLLLLLLLTLLLTLLLLLTTTTLLBLLTTLLLLTTSLLLLSTTTLLTTLLLSLLLL
# prediction: LLLLLLLEEEEETTTTEEEEEELLHHHHHHHHHHHHHHHHHHHHHSLTTSLTTSTTLEEEEEELTTTLSSSTTLLEEEEEEELTTTLLEEEEEELHHHHHHHHHTTLSEEEEESLLSSLEEEEEETTEEEEEEGGGGTTSLHHHHHHHHHHHHLLTTEEEEEELHHHHHTLHHHHHHLLTTLLTLLLHHHHHHHHTTLEEEEEELSSLLLL
# prediction: 
# prediction: ...
# prediction: ...
# ' End single run '
